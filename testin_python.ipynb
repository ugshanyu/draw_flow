# %%
y = {
  "drawflow": {
    "Home": {
      "data": {
        "7": {
          "id": 7,
          "name": "add",
          "data": {},
          "class": "add",
          "html": "add",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": [
                {
                  "node": "8",
                  "input": "output_1"
                }
              ]
            },
            "input_2": {
              "connections": [
                {
                  "node": "9",
                  "input": "output_1"
                }
              ]
            }
          },
          "outputs": {
            "output_1": {
              "connections": []
            }
          },
          "pos_x": 408,
          "pos_y": 125
        },
        "8": {
          "id": 8,
          "name": "input",
          "data": {},
          "class": "input",
          "html": "input",
          "typenode": "vue",
          "inputs": {},
          "outputs": {
            "output_1": {
              "connections": [
                {
                  "node": "7",
                  "output": "input_1"
                }
              ]
            }
          },
          "pos_x": -212.5,
          "pos_y": 42
        },
        "9": {
          "id": 9,
          "name": "input",
          "data": {},
          "class": "input",
          "html": "input",
          "typenode": "vue",
          "inputs": {},
          "outputs": {
            "output_1": {
              "connections": [
                {
                  "node": "7",
                  "output": "input_2"
                }
              ]
            }
          },
          "pos_x": -205,
          "pos_y": 220
        }
      }
    }
  }
}

# %%
def add(input_1, input_2):
    return input_1 + input_2

def run_graph(data):
    nodes = data['drawflow']['Home']['data']
    outputs = {}

    # First, simulate input nodes
    for node_id, node_info in nodes.items():
        if node_info['name'] == 'input':
            # Simulating an input node by assigning a static value
            outputs[node_id] = 5  # Modify to dynamic if necessary

    # Next, execute other nodes
    for node_id, node_info in nodes.items():
        if node_info['name'] == 'add':
            inputs = []
            for input_key, input_value in node_info['inputs'].items():
                # Assuming there's only one connection per input
                source_node = input_value['connections'][0]['node']
                inputs.append(outputs[source_node])
            outputs[node_id] = add(*inputs)

    # Output the results from all nodes
    for node_id, output in outputs.items():
        print(f"Node {node_id} output: {output}")

# %%
run_graph(y)
# Out:
# Node 8 output: 5
# Node 9 output: 5
# Node 7 output: 10

# %%
def generate_python_code(data):
    code = ""

    for module_name, module_data in data["drawflow"].items():
        code += f"# Module: {module_name}\n\n"

        for node_id, node_data in module_data["data"].items():
            node_type = node_data["class"]

            if node_type == "variable":
                variable_key = node_data["data"].get("key", "")
                variable_value = node_data["data"].get("value", "")
                variable_type = node_data["data"].get("type", "string")

                if variable_key and variable_value:
                    code += f"# Variable Node: {node_id}\n"
                    code += f"{variable_key} = "

                    if variable_type == "int":
                        code += f"{int(variable_value)}\n\n"
                    elif variable_type == "boolean":
                        code += f"{variable_value.lower() == 'true'}\n\n"
                    else:
                        code += f'"{variable_value}"\n\n'
                else:
                    code += f"# Variable Node: {node_id}\n"
                    code += "# TODO: Add variable declaration and assignment\n\n"
            # Add more conditions for other node types and generate the corresponding code

    return code

# Example usage
data = {
  "drawflow": {
    "Home": {
      "data": {
        "10": {
          "id": 10,
          "name": "variable",
          "data": {},
          "class": "variable",
          "html": "variable",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": []
            }
          },
          "outputs": {
            "output_1": {
              "connections": []
            }
          },
          "pos_x": 717,
          "pos_y": 354
        }
      }
    }
  }
}
python_code = generate_python_code(data)
print(python_code)
# Out:
# # Module: Home
#
# # Variable Node: 10
# # TODO: Add variable declaration and assignment

# %%
def extract_multiple_data(json_data):
    # Navigate to the 'data' dictionary where multiple entries are stored
    data_entries = json_data['drawflow']['Home']['data']
    
    # List to hold the extracted data objects
    extracted_data = []

    # Loop through each entry in 'data_entries'
    for key, entry in data_entries.items():
        # Extract the relevant data from each entry
        method = entry['data']['data'].get('method', '')
        valueholder = entry['data'].get('valueholder', '')
        key = entry['data'].get('key', '')

        # Append the extracted data to the list
        extracted_data.append({
            "method": method,
            "valueholder": valueholder,
            "key": key
        })

    return extracted_data

# %%
json_input = {
  "drawflow": {
    "Home": {
      "data": {
        "10": {
          "id": 10,
          "name": "variable",
          "data": {
            "id": 10,
            "name": "variable",
            "data": {
              "method": "string"
            },
            "class": "variable",
            "html": "variable",
            "typenode": "vue",
            "inputs": {
              "input_1": {
                "connections": []
              }
            },
            "outputs": {
              "output_1": {
                "connections": []
              }
            },
            "pos_x": 1153.3333129882812,
            "pos_y": 184.3333282470703,
            "valueholder": "HelloHelloHelloHelloHello",
            "key": "What is going on "
          },
          "class": "variable",
          "html": "variable",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": []
            }
          },
          "outputs": {
            "output_1": {
              "connections": []
            }
          },
          "pos_x": 441,
          "pos_y": 137
        },
        "11": {
          "id": 11,
          "name": "variable",
          "data": {
            "id": 11,
            "name": "variable",
            "data": {
              "method": "string"
            },
            "class": "variable",
            "html": "variable",
            "typenode": "vue",
            "inputs": {
              "input_1": {
                "connections": []
              }
            },
            "outputs": {
              "output_1": {
                "connections": []
              }
            },
            "pos_x": 1225.3333129882812,
            "pos_y": 319.3333282470703,
            "valueholder": "method"
          },
          "class": "variable",
          "html": "variable",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": []
            }
          },
          "outputs": {
            "output_1": {
              "connections": []
            }
          },
          "pos_x": 922,
          "pos_y": 137
        }
      }
    }
  }
}

# %%
result = extract_multiple_data(json_input)
print(result)
# Out:
# [{'method': 'string', 'valueholder': 'HelloHelloHelloHelloHello', 'key': 'What is going on '}, {'method': 'string', 'valueholder': 'method', 'key': ''}]

# %%
def extract_data(json_data):
    # Navigate to the 'data' dictionary where the nodes are stored
    nodes = json_data['drawflow']['Home']['data']
    
    # List to hold the extracted data objects
    results = []

    # Loop through each node and extract the required information
    for node_key, node in nodes.items():
        # Check if the node class is 'variable'
        if node['class'].lower() == 'variable':
            node_data = node['data']
            # Navigate deeper into the nested 'data' dictionary to extract the values
            if 'data' in node_data:
                method = node_data['data'].get('method', '')
                valueholder = node_data['data'].get('valueHolder', '')  # Notice the capital 'H'
                key = node_data['data'].get('key', '')
                results.append({
                    "method": method,
                    "valueholder": valueholder,
                    "key": key
                })

    return results

# Example JSON input
json_input = {
  "drawflow": {
    "Home": {
      "data": {
        "10": {
          "id": 10,
          "name": "llmGenerate",
          "data": {
            "id": 10,
            "name": "llmGenerate",
            "data": {
              "systemPrompt": "systemPrompt",
              "userPrompt": "This is System Prompt"
            },
            "class": "llmGenerate",
            "html": "llmGenerate",
            "typenode": "vue",
            "inputs": {
              "input_1": {
                "connections": []
              }
            },
            "outputs": {
              "output_1": {
                "connections": []
              }
            },
            "pos_x": 446,
            "pos_y": 326
          },
          "class": "llmGenerate",
          "html": "llmGenerate",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": []
            }
          },
          "outputs": {
            "output_1": {
              "connections": []
            }
          },
          "pos_x": 451,
          "pos_y": 331
        },
        "11": {
          "id": 11,
          "name": "variable",
          "data": {
            "id": 11,
            "name": "variable",
            "data": {
              "key": "systemPrompt ",
              "valueHolder": "This is System Prompt",
              "method": "string"
            },
            "class": "variable",
            "html": "variable",
            "typenode": "vue",
            "inputs": {
              "input_1": {
                "connections": []
              }
            },
            "outputs": {
              "output_1": {
                "connections": []
              }
            },
            "pos_x": 534.3333129882812,
            "pos_y": 169.3333282470703,
            "key": "systemPrompt ",
            "valueholder": "This is System Prompt"
          },
          "class": "variable",
          "html": "variable",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": []
            }
          },
          "outputs": {
            "output_1": {
              "connections": []
            }
          },
          "pos_x": 452,
          "pos_y": 20
        }
      }
    }
  }
}

# Calling the function with the updated JSON input
extracted_list = extract_data(json_input)
print(extracted_list)
# Out:
# [{'method': 'string', 'valueholder': 'This is System Prompt', 'key': 'systemPrompt '}]

# %%
def handle_variable(node_data):
    # Handle the 'variable' type node
    if 'data' in node_data:
        method = node_data['data'].get('method', '')
        valueholder = node_data['data'].get('valueHolder', '')
        key = node_data['data'].get('key', '')
        return {
            "method": method,
            "valueholder": valueholder,
            "key": key
        }

def handle_llmGenerate(node_data):
    # Handle the 'llmGenerate' type node
    if 'data' in node_data:
        system_prompt = node_data['data'].get('systemPrompt', '')
        user_prompt = node_data['data'].get('userPrompt', '')
        return {
            "systemPrompt": system_prompt,
            "userPrompt": user_prompt
        }

def process_nodes(json_data):
    nodes = json_data['drawflow']['Home']['data']
    results = []

    # Define a dispatcher dictionary to call the right function based on the class type
    dispatcher = {
        'variable': handle_variable,
        'llmgenerate': handle_llmGenerate  # Use lowercase keys for case-insensitive matching
    }

    for node_key, node in nodes.items():
        node_class = node['class'].lower()  # Convert class to lowercase to match dispatcher keys
        if node_class in dispatcher:
            # Call the appropriate function based on the node class
            result = dispatcher[node_class](node['data'])  # Pass the correct part of the node to the handler
            if result:
                results.append(result)

    return results


# Example usage:
extracted_list = process_nodes(json_input)
print(extracted_list)
# Out:
# [{'systemPrompt': 'systemPrompt', 'userPrompt': 'This is System Prompt'}, {'method': 'string', 'valueholder': 'This is System Prompt', 'key': 'systemPrompt '}]

# %%
json_input = {
  "drawflow": {
    "Home": {
      "data": {
        "10": {
          "id": 10,
          "name": "llmGenerate",
          "data": {
            "id": 10,
            "name": "llmGenerate",
            "data": {
              "systemPrompt": "systemPrompt",
              "userPrompt": "This is System Prompt"
            },
            "class": "llmGenerate",
            "html": "llmGenerate",
            "typenode": "vue",
            "inputs": {
              "input_1": {
                "connections": []
              }
            },
            "outputs": {
              "output_1": {
                "connections": []
              }
            },
            "pos_x": 446,
            "pos_y": 326
          },
          "class": "llmGenerate",
          "html": "llmGenerate",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": [
                {
                  "node": "12",
                  "input": "output_1"
                }
              ]
            }
          },
          "outputs": {
            "output_1": {
              "connections": []
            }
          },
          "pos_x": 561,
          "pos_y": 440
        },
        "12": {
          "id": 12,
          "name": "fbWebhook",
          "data": {},
          "class": "fbWebhook",
          "html": "fbWebhook",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": []
            }
          },
          "outputs": {
            "output_1": {
              "connections": [
                {
                  "node": "10",
                  "output": "input_1"
                }
              ]
            }
          },
          "pos_x": 144,
          "pos_y": 483
        }
      }
    }
  }
}

# %%
def create_node_system(json_data):
    nodes = json_data['drawflow']['Home']['data']
    node_system = {}

    for node_id, node_info in nodes.items():
        # Initialize the node system dictionary for each node
        node_system[node_id] = {
            "type": node_info['class'],
            "headNodeId": [],
            "childNodeId": [],
            "internalData": node_info['data']
        }

    # Populate headNodeId and childNodeId based on connections
    for node_id, node_info in nodes.items():
        # Handle outputs to determine child nodes
        if 'outputs' in node_info:
            for output_key, output_value in node_info['outputs'].items():
                for connection in output_value['connections']:
                    child_node_id = connection['node']
                    node_system[node_id]['childNodeId'].append(child_node_id)
                    # Also update the head node information for the connected node
                    if node_id not in node_system[child_node_id]['headNodeId']:
                        node_system[child_node_id]['headNodeId'].append(node_id)

    return node_system

# Example usage:
node_system_output = create_node_system(json_input)
print(node_system_output)
# Out:
# {'10': {'type': 'llmGenerate', 'headNodeId': ['12'], 'childNodeId': [], 'internalData': {'id': 10, 'name': 'llmGenerate', 'data': {'systemPrompt': 'systemPrompt', 'userPrompt': 'This is System Prompt'}, 'class': 'llmGenerate', 'html': 'llmGenerate', 'typenode': 'vue', 'inputs': {'input_1': {'connections': []}}, 'outputs': {'output_1': {'connections': []}}, 'pos_x': 446, 'pos_y': 326}}, '12': {'type': 'fbWebhook', 'headNodeId': [], 'childNodeId': ['10'], 'internalData': {}}}

# %%
node_system_output["10"]
# Out:
# {'type': 'llmGenerate',
#  'headNodeId': ['12'],
#  'childNodeId': [],
#  'internalData': {'id': 10,
#   'name': 'llmGenerate',
#   'data': {'systemPrompt': 'systemPrompt',
#    'userPrompt': 'This is System Prompt'},
#   'class': 'llmGenerate',
#   'html': 'llmGenerate',
#   'typenode': 'vue',
#   'inputs': {'input_1': {'connections': []}},
#   'outputs': {'output_1': {'connections': []}},
#   'pos_x': 446,
#   'pos_y': 326}}

# %%
node_system_output["12"]
# Out:
# {'type': 'fbWebhook',
#  'headNodeId': [],
#  'childNodeId': ['10'],
#  'internalData': {}}

# %%
json_input = {
  "drawflow": {
    "Home": {
      "data": {
        "10": {
          "id": 10,
          "name": "switchCase",
          "data": {
            "id": 10,
            "name": "switchCase",
            "data": {
              "input": "CaseTwo"
            },
            "class": "switchCase",
            "html": "switchCase",
            "typenode": "vue",
            "inputs": {
              "input_1": {
                "connections": [
                  {
                    "node": "11",
                    "input": "output_1"
                  }
                ]
              }
            },
            "outputs": {
              "output_1": {
                "connections": []
              }
            },
            "pos_x": 447,
            "pos_y": 587
          },
          "class": "switchCase",
          "html": "switchCase",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": [
                {
                  "node": "11",
                  "input": "output_1"
                }
              ]
            }
          },
          "outputs": {
            "output_1": {
              "connections": [
                {
                  "node": "16",
                  "output": "input_1"
                }
              ]
            }
          },
          "pos_x": 448,
          "pos_y": 587
        },
        "11": {
          "id": 11,
          "name": "switch",
          "data": {},
          "class": "switch",
          "html": "switch",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": [
                {
                  "node": "14",
                  "input": "output_1"
                }
              ]
            }
          },
          "outputs": {
            "output_1": {
              "connections": [
                {
                  "node": "10",
                  "output": "input_1"
                },
                {
                  "node": "12",
                  "output": "input_1"
                },
                {
                  "node": "13",
                  "output": "input_1"
                }
              ]
            }
          },
          "pos_x": 81,
          "pos_y": 607
        },
        "12": {
          "id": 12,
          "name": "switchCase",
          "data": {
            "id": 12,
            "name": "switchCase",
            "data": {
              "input": "CaseThree"
            },
            "class": "switchCase",
            "html": "switchCase",
            "typenode": "vue",
            "inputs": {
              "input_1": {
                "connections": [
                  {
                    "node": "11",
                    "input": "output_1"
                  }
                ]
              }
            },
            "outputs": {
              "output_1": {
                "connections": []
              }
            },
            "pos_x": 442,
            "pos_y": 828
          },
          "class": "switchCase",
          "html": "switchCase",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": [
                {
                  "node": "11",
                  "input": "output_1"
                }
              ]
            }
          },
          "outputs": {
            "output_1": {
              "connections": [
                {
                  "node": "17",
                  "output": "input_1"
                }
              ]
            }
          },
          "pos_x": 445,
          "pos_y": 827
        },
        "13": {
          "id": 13,
          "name": "switchCase",
          "data": {
            "id": 13,
            "name": "switchCase",
            "data": {
              "input": "caseOne"
            },
            "class": "switchCase",
            "html": "switchCase",
            "typenode": "vue",
            "inputs": {
              "input_1": {
                "connections": [
                  {
                    "node": "11",
                    "input": "output_1"
                  }
                ]
              }
            },
            "outputs": {
              "output_1": {
                "connections": [
                  {
                    "node": "15",
                    "output": "input_1"
                  }
                ]
              }
            },
            "pos_x": 451,
            "pos_y": 301
          },
          "class": "switchCase",
          "html": "switchCase",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": [
                {
                  "node": "11",
                  "input": "output_1"
                }
              ]
            }
          },
          "outputs": {
            "output_1": {
              "connections": [
                {
                  "node": "15",
                  "output": "input_1"
                }
              ]
            }
          },
          "pos_x": 451,
          "pos_y": 301
        },
        "14": {
          "id": 14,
          "name": "llmGenerate",
          "data": {
            "id": 14,
            "name": "llmGenerate",
            "data": {
              "systemPrompt": "IceTop",
              "userPrompt": "Hello"
            },
            "class": "llmGenerate",
            "html": "llmGenerate",
            "typenode": "vue",
            "inputs": {
              "input_1": {
                "connections": []
              }
            },
            "outputs": {
              "output_1": {
                "connections": []
              }
            },
            "pos_x": -447,
            "pos_y": 557
          },
          "class": "llmGenerate",
          "html": "llmGenerate",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": []
            }
          },
          "outputs": {
            "output_1": {
              "connections": [
                {
                  "node": "11",
                  "output": "input_1"
                }
              ]
            }
          },
          "pos_x": -453,
          "pos_y": 564
        },
        "15": {
          "id": 15,
          "name": "llmGenerate",
          "data": {
            "id": 15,
            "name": "llmGenerate",
            "data": {
              "systemPrompt": "caseOneTest",
              "userPrompt": "on"
            },
            "class": "llmGenerate",
            "html": "llmGenerate",
            "typenode": "vue",
            "inputs": {
              "input_1": {
                "connections": [
                  {
                    "node": "13",
                    "input": "output_1"
                  }
                ]
              }
            },
            "outputs": {
              "output_1": {
                "connections": []
              }
            },
            "pos_x": 857,
            "pos_y": 272
          },
          "class": "llmGenerate",
          "html": "llmGenerate",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": [
                {
                  "node": "13",
                  "input": "output_1"
                }
              ]
            }
          },
          "outputs": {
            "output_1": {
              "connections": []
            }
          },
          "pos_x": 871.75,
          "pos_y": 273.75
        },
        "16": {
          "id": 16,
          "name": "llmGenerate",
          "data": {
            "id": 16,
            "name": "llmGenerate",
            "data": {
              "systemPrompt": "CaseTwoTest",
              "userPrompt": "me"
            },
            "class": "llmGenerate",
            "html": "llmGenerate",
            "typenode": "vue",
            "inputs": {
              "input_1": {
                "connections": [
                  {
                    "node": "10",
                    "input": "output_1"
                  }
                ]
              }
            },
            "outputs": {
              "output_1": {
                "connections": []
              }
            },
            "pos_x": 856,
            "pos_y": 557
          },
          "class": "llmGenerate",
          "html": "llmGenerate",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": [
                {
                  "node": "10",
                  "input": "output_1"
                }
              ]
            }
          },
          "outputs": {
            "output_1": {
              "connections": []
            }
          },
          "pos_x": 856,
          "pos_y": 557
        },
        "17": {
          "id": 17,
          "name": "llmGenerate",
          "data": {
            "id": 17,
            "name": "llmGenerate",
            "data": {
              "systemPrompt": "CaseThreeTest",
              "userPrompt": "Why"
            },
            "class": "llmGenerate",
            "html": "llmGenerate",
            "typenode": "vue",
            "inputs": {
              "input_1": {
                "connections": [
                  {
                    "node": "12",
                    "input": "output_1"
                  }
                ]
              }
            },
            "outputs": {
              "output_1": {
                "connections": []
              }
            },
            "pos_x": 875,
            "pos_y": 802
          },
          "class": "llmGenerate",
          "html": "llmGenerate",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": [
                {
                  "node": "12",
                  "input": "output_1"
                }
              ]
            }
          },
          "outputs": {
            "output_1": {
              "connections": []
            }
          },
          "pos_x": 875,
          "pos_y": 802
        },
        "20": {
          "id": 20,
          "name": "globalVariable",
          "data": {
            "id": 20,
            "name": "globalVariable",
            "data": {
              "key": "IceTop",
              "valueHolder": "Hello",
              "method": "string"
            },
            "class": "globalVariable",
            "html": "globalVariable",
            "typenode": "vue",
            "inputs": {},
            "outputs": {},
            "pos_x": 129.69045003255223,
            "pos_y": -27.83335367838538,
            "key": "IceTop",
            "valueholder": "Hello"
          },
          "class": "globalVariable",
          "html": "globalVariable",
          "typenode": "vue",
          "inputs": {},
          "outputs": {},
          "pos_x": -454.57142857142856,
          "pos_y": 239
        }
      }
    }
  }
}

# %%
def create_node_system(json_data):
    nodes = json_data['drawflow']['Home']['data']
    node_system = {}

    for node_id, node_info in nodes.items():
        # Initialize the node system dictionary for each node
        # Ensure internalData points to the innermost 'data' dictionary if it exists
        internal_data = node_info['data']['data'] if 'data' in node_info['data'] else {}
        node_system[node_id] = {
            "type": node_info['class'],
            "headNodeId": [],
            "childNodeId": [],
            "internalData": internal_data
        }

    # Populate headNodeId and childNodeId based on connections
    for node_id, node_info in nodes.items():
        # Handle outputs to determine child nodes
        if 'outputs' in node_info:
            for output_key, output_value in node_info['outputs'].items():
                for connection in output_value['connections']:
                    child_node_id = connection['node']
                    node_system[node_id]['childNodeId'].append(child_node_id)
                    # Also update the head node information for the connected node
                    if node_id not in node_system[child_node_id]['headNodeId']:
                        node_system[child_node_id]['headNodeId'].append(node_id)

    return node_system

# Example usage:
node_system_output = create_node_system(json_input)
print(node_system_output)
# Out:
# {'10': {'type': 'switchCase', 'headNodeId': ['11'], 'childNodeId': ['16'], 'internalData': {'input': 'CaseTwo'}}, '11': {'type': 'switch', 'headNodeId': ['14'], 'childNodeId': ['10', '12', '13'], 'internalData': {}}, '12': {'type': 'switchCase', 'headNodeId': ['11'], 'childNodeId': ['17'], 'internalData': {'input': 'CaseThree'}}, '13': {'type': 'switchCase', 'headNodeId': ['11'], 'childNodeId': ['15'], 'internalData': {'input': 'caseOne'}}, '14': {'type': 'llmGenerate', 'headNodeId': [], 'childNodeId': ['11'], 'internalData': {'systemPrompt': 'IceTop', 'userPrompt': 'Hello'}}, '15': {'type': 'llmGenerate', 'headNodeId': ['13'], 'childNodeId': [], 'internalData': {'systemPrompt': 'caseOneTest', 'userPrompt': 'on'}}, '16': {'type': 'llmGenerate', 'headNodeId': ['10'], 'childNodeId': [], 'internalData': {'systemPrompt': 'CaseTwoTest', 'userPrompt': 'me'}}, '17': {'type': 'llmGenerate', 'headNodeId': ['12'], 'childNodeId': [], 'internalData': {'systemPrompt': 'CaseThreeTest', 'userPrompt': 'Why'}}, '20': {'type': 'globalVariable', 'headNodeId': [], 'childNodeId': [], 'internalData': {'key': 'IceTop', 'valueHolder': 'Hello', 'method': 'string'}}}

# %%
node_system_output
# Out:
# {'10': {'type': 'switchCase',
#   'headNodeId': ['11'],
#   'childNodeId': ['16'],
#   'internalData': {'input': 'CaseTwo'}},
#  '11': {'type': 'switch',
#   'headNodeId': ['14'],
#   'childNodeId': ['10', '12', '13'],
#   'internalData': {}},
#  '12': {'type': 'switchCase',
#   'headNodeId': ['11'],
#   'childNodeId': ['17'],
#   'internalData': {'input': 'CaseThree'}},
#  '13': {'type': 'switchCase',
#   'headNodeId': ['11'],
#   'childNodeId': ['15'],
#   'internalData': {'input': 'caseOne'}},
#  '14': {'type': 'llmGenerate',
#   'headNodeId': [],
#   'childNodeId': ['11'],
#   'internalData': {'systemPrompt': 'IceTop', 'userPrompt': 'Hello'}},
#  '15': {'type': 'llmGenerate',
#   'headNodeId': ['13'],
#   'childNodeId': [],
#   'internalData': {'systemPrompt': 'caseOneTest', 'userPrompt': 'on'}},
#  '16': {'type': 'llmGenerate',
#   'headNodeId': ['10'],
#   'childNodeId': [],
#   'internalData': {'systemPrompt': 'CaseTwoTest', 'userPrompt': 'me'}},
#  '17': {'type': 'llmGenerate',
#   'headNodeId': ['12'],
#   'childNodeId': [],
#   'internalData': {'systemPrompt': 'CaseThreeTest', 'userPrompt': 'Why'}},
#  '20': {'type': 'globalVariable',
#   'headNodeId': [],
#   'childNodeId': [],
#   'internalData': {'key': 'IceTop',
#    'valueHolder': 'Hello',
#    'method': 'string'}}}

# %%
import json

def generate_code(node_system):
    code = []  # Initialize code as an empty list
    global_variables = {}

    # Extract global variables
    for node_id, node_data in node_system.items():
        if node_data['type'] == 'globalVariable':
            key = node_data['internalData']['key']
            value = node_data['internalData']['valueHolder']
            method = node_data['internalData']['method']
            global_variables[key] = (value, method)

    # Generate global variable assignments
    for key, (value, method) in global_variables.items():
        if method == 'string':
            code.append(f"{key} = '{value}'\n")
        else:
            code.append(f"{key} = {value}\n")

    # Find the starting node
    start_node_id = None
    for node_id, node_data in node_system.items():
        if node_data['type'] == 'llmGenerate' and not node_data['headNodeId']:
            start_node_id = node_id
            break

    # Generate code for each node
    visited_nodes = set()
    def generate_node_code(node_id, indent="", head_node_id=None):
        if node_id in visited_nodes:
            return
        visited_nodes.add(node_id)

        node_data = node_system[node_id]
        node_type = node_data['type']

        if node_type == 'llmGenerate':
            system_prompt = node_data['internalData']['systemPrompt']
            user_prompt = node_data['internalData']['userPrompt']
            code_line = f"{indent}llmGenerate('{system_prompt}', '{user_prompt}', {head_node_id})\n"
            code_line = f"{indent}{node_id} = " + code_line
            code.append(code_line)
            for child_node_id in node_data['childNodeId']:
                generate_node_code(child_node_id, indent, node_id)

        elif node_type == 'switch':
            code.append(f"{indent}match {node_data['headNodeId'][0]}:\n")
            for child_node_id in node_data['childNodeId']:
                generate_node_code(child_node_id, indent + "    ", node_data['headNodeId'][0])

        elif node_type == 'switchCase':
            input_value = node_data['internalData']['input']
            code.append(f"{indent}case '{input_value}':\n")
            for child_node_id in node_data['childNodeId']:
                generate_node_code(child_node_id, indent + "    ", head_node_id)

    generate_node_code(start_node_id)
    return "\n".join(code)

# Example usage
generated_code = generate_code(node_system_output)
print(generated_code)
# Out:
# IceTop = 'Hello'
#
# 14 = llmGenerate('IceTop', 'Hello', None)
#
# match 14:
#
#     case 'CaseTwo':
#
#         16 =         llmGenerate('CaseTwoTest', 'me', 14)
#
#     case 'CaseThree':
#
#         17 =         llmGenerate('CaseThreeTest', 'Why', 14)
#
#     case 'caseOne':
#
#         15 =         llmGenerate('caseOneTest', 'on', 14)

# %%
import json

def generate_code(node_system):
    code = []  # Initialize code as an empty list
    global_variables = {}

    # Extract global variables
    for node_id, node_data in node_system.items():
        if node_data['type'] == 'globalVariable':
            key = node_data['internalData']['key']
            value = node_data['internalData']['valueHolder']
            method = node_data['internalData']['method']
            global_variables[key] = (value, method)

    # Generate global variable assignments
    for key, (value, method) in global_variables.items():
        if method == 'string':
            code.append(f"{key} = '{value}'\n")
        else:
            code.append(f"{key} = {value}\n")

    # Find the starting node
    start_node_id = None
    for node_id, node_data in node_system.items():
        if node_data['type'] == 'llmGenerate' and not node_data['headNodeId']:
            start_node_id = node_id
            break

    # Generate code for each node
    visited_nodes = set()
    def generate_node_code(node_id, indent="", head_node_id=None):
        if node_id in visited_nodes:
            return
        visited_nodes.add(node_id)

        node_data = node_system[node_id]
        node_type = node_data['type']

        if node_type == 'llmGenerate':
            system_prompt = node_data['internalData']['systemPrompt']
            user_prompt = node_data['internalData']['userPrompt']
            code_line = f"{indent}llmGenerate('{system_prompt}', '{user_prompt}', {head_node_id})\n"
            code_line = f"{indent}node{node_id} = " + code_line
            code.append(code_line)
            for child_node_id in node_data['childNodeId']:
                generate_node_code(child_node_id, indent, f"node{node_id}")

        elif node_type == 'switch':
            code.append(f"{indent}match node{node_data['headNodeId'][0]}:\n")
            for child_node_id in node_data['childNodeId']:
                generate_node_code(child_node_id, indent + "    ", f"node{node_data['headNodeId'][0]}")

        elif node_type == 'switchCase':
            input_value = node_data['internalData']['input']
            code.append(f"{indent}case '{input_value}':\n")
            for child_node_id in node_data['childNodeId']:
                generate_node_code(child_node_id, indent + "    ", head_node_id)

    generate_node_code(start_node_id)
    return "\n".join(code)

# Example usage
generated_code = generate_code(node_system_output)
print(generated_code)

#write to file
with open('generated_code.py', 'w') as f:
    f.write(generated_code)
# Out:
# IceTop = 'Hello'
#
# node14 = llmGenerate('IceTop', 'Hello', None)
#
# match node14:
#
#     case 'CaseTwo':
#
#         node16 =         llmGenerate('CaseTwoTest', 'me', node14)
#
#     case 'CaseThree':
#
#         node17 =         llmGenerate('CaseThreeTest', 'Why', node14)
#
#     case 'caseOne':
#
#         node15 =         llmGenerate('caseOneTest', 'on', node14)
