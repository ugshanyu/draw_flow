# %%
y = {
  "drawflow": {
    "Home": {
      "data": {
        "7": {
          "id": 7,
          "name": "add",
          "data": {},
          "class": "add",
          "html": "add",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": [
                {
                  "node": "8",
                  "input": "output_1"
                }
              ]
            },
            "input_2": {
              "connections": [
                {
                  "node": "9",
                  "input": "output_1"
                }
              ]
            }
          },
          "outputs": {
            "output_1": {
              "connections": []
            }
          },
          "pos_x": 408,
          "pos_y": 125
        },
        "8": {
          "id": 8,
          "name": "input",
          "data": {},
          "class": "input",
          "html": "input",
          "typenode": "vue",
          "inputs": {},
          "outputs": {
            "output_1": {
              "connections": [
                {
                  "node": "7",
                  "output": "input_1"
                }
              ]
            }
          },
          "pos_x": -212.5,
          "pos_y": 42
        },
        "9": {
          "id": 9,
          "name": "input",
          "data": {},
          "class": "input",
          "html": "input",
          "typenode": "vue",
          "inputs": {},
          "outputs": {
            "output_1": {
              "connections": [
                {
                  "node": "7",
                  "output": "input_2"
                }
              ]
            }
          },
          "pos_x": -205,
          "pos_y": 220
        }
      }
    }
  }
}

# %%
def add(input_1, input_2):
    return input_1 + input_2

def run_graph(data):
    nodes = data['drawflow']['Home']['data']
    outputs = {}

    # First, simulate input nodes
    for node_id, node_info in nodes.items():
        if node_info['name'] == 'input':
            # Simulating an input node by assigning a static value
            outputs[node_id] = 5  # Modify to dynamic if necessary

    # Next, execute other nodes
    for node_id, node_info in nodes.items():
        if node_info['name'] == 'add':
            inputs = []
            for input_key, input_value in node_info['inputs'].items():
                # Assuming there's only one connection per input
                source_node = input_value['connections'][0]['node']
                inputs.append(outputs[source_node])
            outputs[node_id] = add(*inputs)

    # Output the results from all nodes
    for node_id, output in outputs.items():
        print(f"Node {node_id} output: {output}")

# %%
run_graph(y)
# Out:
# Node 8 output: 5
# Node 9 output: 5
# Node 7 output: 10

# %%
def generate_python_code(data):
    code = ""

    for module_name, module_data in data["drawflow"].items():
        code += f"# Module: {module_name}\n\n"

        for node_id, node_data in module_data["data"].items():
            node_type = node_data["class"]

            if node_type == "variable":
                variable_key = node_data["data"].get("key", "")
                variable_value = node_data["data"].get("value", "")
                variable_type = node_data["data"].get("type", "string")

                if variable_key and variable_value:
                    code += f"# Variable Node: {node_id}\n"
                    code += f"{variable_key} = "

                    if variable_type == "int":
                        code += f"{int(variable_value)}\n\n"
                    elif variable_type == "boolean":
                        code += f"{variable_value.lower() == 'true'}\n\n"
                    else:
                        code += f'"{variable_value}"\n\n'
                else:
                    code += f"# Variable Node: {node_id}\n"
                    code += "# TODO: Add variable declaration and assignment\n\n"
            # Add more conditions for other node types and generate the corresponding code

    return code

# Example usage
data = {
  "drawflow": {
    "Home": {
      "data": {
        "10": {
          "id": 10,
          "name": "variable",
          "data": {},
          "class": "variable",
          "html": "variable",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": []
            }
          },
          "outputs": {
            "output_1": {
              "connections": []
            }
          },
          "pos_x": 717,
          "pos_y": 354
        }
      }
    }
  }
}
python_code = generate_python_code(data)
print(python_code)
# Out:
# # Module: Home
#
# # Variable Node: 10
# # TODO: Add variable declaration and assignment

# %%
def extract_multiple_data(json_data):
    # Navigate to the 'data' dictionary where multiple entries are stored
    data_entries = json_data['drawflow']['Home']['data']
    
    # List to hold the extracted data objects
    extracted_data = []

    # Loop through each entry in 'data_entries'
    for key, entry in data_entries.items():
        # Extract the relevant data from each entry
        method = entry['data']['data'].get('method', '')
        valueholder = entry['data'].get('valueholder', '')
        key = entry['data'].get('key', '')

        # Append the extracted data to the list
        extracted_data.append({
            "method": method,
            "valueholder": valueholder,
            "key": key
        })

    return extracted_data

# %%
json_input = {
  "drawflow": {
    "Home": {
      "data": {
        "10": {
          "id": 10,
          "name": "variable",
          "data": {
            "id": 10,
            "name": "variable",
            "data": {
              "method": "string"
            },
            "class": "variable",
            "html": "variable",
            "typenode": "vue",
            "inputs": {
              "input_1": {
                "connections": []
              }
            },
            "outputs": {
              "output_1": {
                "connections": []
              }
            },
            "pos_x": 1153.3333129882812,
            "pos_y": 184.3333282470703,
            "valueholder": "HelloHelloHelloHelloHello",
            "key": "What is going on "
          },
          "class": "variable",
          "html": "variable",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": []
            }
          },
          "outputs": {
            "output_1": {
              "connections": []
            }
          },
          "pos_x": 441,
          "pos_y": 137
        },
        "11": {
          "id": 11,
          "name": "variable",
          "data": {
            "id": 11,
            "name": "variable",
            "data": {
              "method": "string"
            },
            "class": "variable",
            "html": "variable",
            "typenode": "vue",
            "inputs": {
              "input_1": {
                "connections": []
              }
            },
            "outputs": {
              "output_1": {
                "connections": []
              }
            },
            "pos_x": 1225.3333129882812,
            "pos_y": 319.3333282470703,
            "valueholder": "method"
          },
          "class": "variable",
          "html": "variable",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": []
            }
          },
          "outputs": {
            "output_1": {
              "connections": []
            }
          },
          "pos_x": 922,
          "pos_y": 137
        }
      }
    }
  }
}

# %%
result = extract_multiple_data(json_input)
print(result)
# Out:
# [{'method': 'string', 'valueholder': 'HelloHelloHelloHelloHello', 'key': 'What is going on '}, {'method': 'string', 'valueholder': 'method', 'key': ''}]

# %%
def extract_data(json_data):
    # Navigate to the 'data' dictionary where the nodes are stored
    nodes = json_data['drawflow']['Home']['data']
    
    # List to hold the extracted data objects
    results = []

    # Loop through each node and extract the required information
    for node_key, node in nodes.items():
        # Check if the node class is 'variable'
        if node['class'].lower() == 'variable':
            node_data = node['data']
            # Navigate deeper into the nested 'data' dictionary to extract the values
            if 'data' in node_data:
                method = node_data['data'].get('method', '')
                valueholder = node_data['data'].get('valueHolder', '')  # Notice the capital 'H'
                key = node_data['data'].get('key', '')
                results.append({
                    "method": method,
                    "valueholder": valueholder,
                    "key": key
                })

    return results

# Example JSON input
json_input = {
  "drawflow": {
    "Home": {
      "data": {
        "10": {
          "id": 10,
          "name": "llmGenerate",
          "data": {
            "id": 10,
            "name": "llmGenerate",
            "data": {
              "systemPrompt": "systemPrompt",
              "userPrompt": "This is System Prompt"
            },
            "class": "llmGenerate",
            "html": "llmGenerate",
            "typenode": "vue",
            "inputs": {
              "input_1": {
                "connections": []
              }
            },
            "outputs": {
              "output_1": {
                "connections": []
              }
            },
            "pos_x": 446,
            "pos_y": 326
          },
          "class": "llmGenerate",
          "html": "llmGenerate",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": []
            }
          },
          "outputs": {
            "output_1": {
              "connections": []
            }
          },
          "pos_x": 451,
          "pos_y": 331
        },
        "11": {
          "id": 11,
          "name": "variable",
          "data": {
            "id": 11,
            "name": "variable",
            "data": {
              "key": "systemPrompt ",
              "valueHolder": "This is System Prompt",
              "method": "string"
            },
            "class": "variable",
            "html": "variable",
            "typenode": "vue",
            "inputs": {
              "input_1": {
                "connections": []
              }
            },
            "outputs": {
              "output_1": {
                "connections": []
              }
            },
            "pos_x": 534.3333129882812,
            "pos_y": 169.3333282470703,
            "key": "systemPrompt ",
            "valueholder": "This is System Prompt"
          },
          "class": "variable",
          "html": "variable",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": []
            }
          },
          "outputs": {
            "output_1": {
              "connections": []
            }
          },
          "pos_x": 452,
          "pos_y": 20
        }
      }
    }
  }
}

# Calling the function with the updated JSON input
extracted_list = extract_data(json_input)
print(extracted_list)
# Out:
# [{'method': 'string', 'valueholder': 'This is System Prompt', 'key': 'systemPrompt '}]

# %%
def handle_variable(node_data):
    # Handle the 'variable' type node
    if 'data' in node_data:
        method = node_data['data'].get('method', '')
        valueholder = node_data['data'].get('valueHolder', '')
        key = node_data['data'].get('key', '')
        return {
            "method": method,
            "valueholder": valueholder,
            "key": key
        }

def handle_llmGenerate(node_data):
    # Handle the 'llmGenerate' type node
    if 'data' in node_data:
        system_prompt = node_data['data'].get('systemPrompt', '')
        user_prompt = node_data['data'].get('userPrompt', '')
        return {
            "systemPrompt": system_prompt,
            "userPrompt": user_prompt
        }

def process_nodes(json_data):
    nodes = json_data['drawflow']['Home']['data']
    results = []

    # Define a dispatcher dictionary to call the right function based on the class type
    dispatcher = {
        'variable': handle_variable,
        'llmgenerate': handle_llmGenerate  # Use lowercase keys for case-insensitive matching
    }

    for node_key, node in nodes.items():
        node_class = node['class'].lower()  # Convert class to lowercase to match dispatcher keys
        if node_class in dispatcher:
            # Call the appropriate function based on the node class
            result = dispatcher[node_class](node['data'])  # Pass the correct part of the node to the handler
            if result:
                results.append(result)

    return results


# Example usage:
extracted_list = process_nodes(json_input)
print(extracted_list)
# Out:
# [{'systemPrompt': 'systemPrompt', 'userPrompt': 'This is System Prompt'}, {'method': 'string', 'valueholder': 'This is System Prompt', 'key': 'systemPrompt '}]

# %%
json_input = {
  "drawflow": {
    "Home": {
      "data": {
        "10": {
          "id": 10,
          "name": "llmGenerate",
          "data": {
            "id": 10,
            "name": "llmGenerate",
            "data": {
              "systemPrompt": "systemPrompt",
              "userPrompt": "This is System Prompt"
            },
            "class": "llmGenerate",
            "html": "llmGenerate",
            "typenode": "vue",
            "inputs": {
              "input_1": {
                "connections": []
              }
            },
            "outputs": {
              "output_1": {
                "connections": []
              }
            },
            "pos_x": 446,
            "pos_y": 326
          },
          "class": "llmGenerate",
          "html": "llmGenerate",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": [
                {
                  "node": "12",
                  "input": "output_1"
                }
              ]
            }
          },
          "outputs": {
            "output_1": {
              "connections": []
            }
          },
          "pos_x": 561,
          "pos_y": 440
        },
        "12": {
          "id": 12,
          "name": "fbWebhook",
          "data": {},
          "class": "fbWebhook",
          "html": "fbWebhook",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": []
            }
          },
          "outputs": {
            "output_1": {
              "connections": [
                {
                  "node": "10",
                  "output": "input_1"
                }
              ]
            }
          },
          "pos_x": 144,
          "pos_y": 483
        }
      }
    }
  }
}

# %%
def create_node_system(json_data):
    nodes = json_data['drawflow']['Home']['data']
    node_system = {}

    for node_id, node_info in nodes.items():
        # Initialize the node system dictionary for each node
        node_system[node_id] = {
            "type": node_info['class'],
            "headNodeId": [],
            "childNodeId": [],
            "internalData": node_info['data']
        }

    # Populate headNodeId and childNodeId based on connections
    for node_id, node_info in nodes.items():
        # Handle outputs to determine child nodes
        if 'outputs' in node_info:
            for output_key, output_value in node_info['outputs'].items():
                for connection in output_value['connections']:
                    child_node_id = connection['node']
                    node_system[node_id]['childNodeId'].append(child_node_id)
                    # Also update the head node information for the connected node
                    if node_id not in node_system[child_node_id]['headNodeId']:
                        node_system[child_node_id]['headNodeId'].append(node_id)

    return node_system

# Example usage:
node_system_output = create_node_system(json_input)
print(node_system_output)
# Out:
# {'10': {'type': 'llmGenerate', 'headNodeId': ['12'], 'childNodeId': [], 'internalData': {'id': 10, 'name': 'llmGenerate', 'data': {'systemPrompt': 'systemPrompt', 'userPrompt': 'This is System Prompt'}, 'class': 'llmGenerate', 'html': 'llmGenerate', 'typenode': 'vue', 'inputs': {'input_1': {'connections': []}}, 'outputs': {'output_1': {'connections': []}}, 'pos_x': 446, 'pos_y': 326}}, '12': {'type': 'fbWebhook', 'headNodeId': [], 'childNodeId': ['10'], 'internalData': {}}}

# %%
node_system_output["10"]
# Out:
# {'type': 'llmGenerate',
#  'headNodeId': ['12'],
#  'childNodeId': [],
#  'internalData': {'id': 10,
#   'name': 'llmGenerate',
#   'data': {'systemPrompt': 'systemPrompt',
#    'userPrompt': 'This is System Prompt'},
#   'class': 'llmGenerate',
#   'html': 'llmGenerate',
#   'typenode': 'vue',
#   'inputs': {'input_1': {'connections': []}},
#   'outputs': {'output_1': {'connections': []}},
#   'pos_x': 446,
#   'pos_y': 326}}

# %%
node_system_output["12"]
# Out:
# {'type': 'fbWebhook',
#  'headNodeId': [],
#  'childNodeId': ['10'],
#  'internalData': {}}

# %%
json_input = {
  "drawflow": {
    "Home": {
      "data": {
        "10": {
          "id": 10,
          "name": "fbWebhook",
          "data": {},
          "class": "fbWebhook",
          "html": "fbWebhook",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": []
            }
          },
          "outputs": {
            "output_1": {
              "connections": [
                {
                  "node": "11",
                  "output": "input_1"
                }
              ]
            }
          },
          "pos_x": 85,
          "pos_y": 433
        },
        "11": {
          "id": 11,
          "name": "llmGenerate",
          "data": {
            "id": 11,
            "name": "llmGenerate",
            "data": {
              "systemPrompt": "Hello",
              "userPrompt": "World"
            },
            "class": "llmGenerate",
            "html": "llmGenerate",
            "typenode": "vue",
            "inputs": {
              "input_1": {
                "connections": [
                  {
                    "node": "10",
                    "input": "output_1"
                  }
                ]
              }
            },
            "outputs": {
              "output_1": {
                "connections": [
                  {
                    "node": "12",
                    "output": "input_1"
                  }
                ]
              }
            },
            "pos_x": 456,
            "pos_y": 386
          },
          "class": "llmGenerate",
          "html": "llmGenerate",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": [
                {
                  "node": "10",
                  "input": "output_1"
                }
              ]
            }
          },
          "outputs": {
            "output_1": {
              "connections": [
                {
                  "node": "12",
                  "output": "input_1"
                }
              ]
            }
          },
          "pos_x": 456,
          "pos_y": 386
        },
        "12": {
          "id": 12,
          "name": "switch",
          "data": {},
          "class": "switch",
          "html": "switch",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": [
                {
                  "node": "11",
                  "input": "output_1"
                }
              ]
            }
          },
          "outputs": {
            "output_1": {
              "connections": [
                {
                  "node": "13",
                  "output": "input_1"
                },
                {
                  "node": "14",
                  "output": "input_1"
                }
              ]
            }
          },
          "pos_x": 873,
          "pos_y": 431
        },
        "13": {
          "id": 13,
          "name": "switchCase",
          "data": {},
          "class": "switchCase",
          "html": "switchCase",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": [
                {
                  "node": "12",
                  "input": "output_1"
                }
              ]
            }
          },
          "outputs": {
            "output_1": {
              "connections": []
            }
          },
          "pos_x": 1229,
          "pos_y": 518
        },
        "14": {
          "id": 14,
          "name": "switchCase",
          "data": {},
          "class": "switchCase",
          "html": "switchCase",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": [
                {
                  "node": "12",
                  "input": "output_1"
                }
              ]
            }
          },
          "outputs": {
            "output_1": {
              "connections": []
            }
          },
          "pos_x": 1241,
          "pos_y": 275
        }
      }
    }
  }
}

# %%
def create_node_system(json_data):
    nodes = json_data['drawflow']['Home']['data']
    node_system = {}

    for node_id, node_info in nodes.items():
        # Initialize the node system dictionary for each node
        # Ensure internalData points to the innermost 'data' dictionary if it exists
        internal_data = node_info['data']['data'] if 'data' in node_info['data'] else {}
        node_system[node_id] = {
            "type": node_info['class'],
            "headNodeId": [],
            "childNodeId": [],
            "internalData": internal_data
        }

    # Populate headNodeId and childNodeId based on connections
    for node_id, node_info in nodes.items():
        # Handle outputs to determine child nodes
        if 'outputs' in node_info:
            for output_key, output_value in node_info['outputs'].items():
                for connection in output_value['connections']:
                    child_node_id = connection['node']
                    node_system[node_id]['childNodeId'].append(child_node_id)
                    # Also update the head node information for the connected node
                    if node_id not in node_system[child_node_id]['headNodeId']:
                        node_system[child_node_id]['headNodeId'].append(node_id)

    return node_system

# Example usage:
node_system_output = create_node_system(json_input)
print(node_system_output)

# Output for node "10"
print(node_system_output["10"])

# Output for node "12"
print(node_system_output["11"])
print(node_system_output["12"])
print(node_system_output["13"])
print(node_system_output["14"])
# Out:
# {'10': {'type': 'fbWebhook', 'headNodeId': [], 'childNodeId': ['11'], 'internalData': {}}, '11': {'type': 'llmGenerate', 'headNodeId': ['10'], 'childNodeId': ['12'], 'internalData': {'systemPrompt': 'Hello', 'userPrompt': 'World'}}, '12': {'type': 'switch', 'headNodeId': ['11'], 'childNodeId': ['13', '14'], 'internalData': {}}, '13': {'type': 'switchCase', 'headNodeId': ['12'], 'childNodeId': [], 'internalData': {}}, '14': {'type': 'switchCase', 'headNodeId': ['12'], 'childNodeId': [], 'internalData': {}}}
# {'type': 'fbWebhook', 'headNodeId': [], 'childNodeId': ['11'], 'internalData': {}}
# {'type': 'llmGenerate', 'headNodeId': ['10'], 'childNodeId': ['12'], 'internalData': {'systemPrompt': 'Hello', 'userPrompt': 'World'}}
# {'type': 'switch', 'headNodeId': ['11'], 'childNodeId': ['13', '14'], 'internalData': {}}
# {'type': 'switchCase', 'headNodeId': ['12'], 'childNodeId': [], 'internalData': {}}
# {'type': 'switchCase', 'headNodeId': ['12'], 'childNodeId': [], 'internalData': {}}

# %%
node_system_output
# Out:
# {'10': {'type': 'fbWebhook',
#   'headNodeId': [],
#   'childNodeId': ['11'],
#   'internalData': {}},
#  '11': {'type': 'llmGenerate',
#   'headNodeId': ['10'],
#   'childNodeId': [],
#   'internalData': {'systemPrompt': 'thinking', 'userPrompt': 'world'}},
#  '12': {'type': 'globalVariable',
#   'headNodeId': [],
#   'childNodeId': [],
#   'internalData': {'key': 'thinking',
#    'valueHolder': 'World',
#    'method': 'int'}}}

# %%
# import json

# def llmGenerate(system_prompt, user_prompt):
#     print("system_prompt", system_prompt)
#     print("user_prompt", user_prompt)
#     # Placeholder function for llmGenerate
#     return f"Generated response for system prompt: {system_prompt}, user prompt: {user_prompt}"

# def execute_node_system(node_system):
#     global_vars = {}

#     #Before we process we loop through all nodes and check if there is 

#     def process_node(node_id):
#         node = node_system[node_id]
#         node_type = node['type']

#         if node_type == 'fbWebhook':
#             for child_node_id in node['childNodeId']:
#                 process_node(child_node_id)
#         elif node_type == 'llmGenerate':
#             system_prompt = node['internalData']['systemPrompt']
#             user_prompt = node['internalData']['userPrompt']
#             response = llmGenerate(system_prompt, user_prompt)
#         elif node_type == 'variable':
#             key = node['internalData']['key']
#             value = node['internalData']['valueHolder']
#             global_vars[key] = value

#     for node_id in node_system:
#         if node_system[node_id]['type'] == 'fbWebhook':
#             process_node(node_id)

# %%
# execute_node_system(node_system_output)
# Out:
# system_prompt systemPrompt
# user_prompt This is System Prompt
# Generated response for system prompt: systemPrompt, user prompt: This is System Prompt

# %%
node_system_output
# Out:
# {'10': {'type': 'fbWebhook',
#   'headNodeId': [],
#   'childNodeId': ['11'],
#   'internalData': {}},
#  '11': {'type': 'llmGenerate',
#   'headNodeId': ['10'],
#   'childNodeId': [],
#   'internalData': {'systemPrompt': 'thinking', 'userPrompt': 'world'}},
#  '12': {'type': 'globalVariable',
#   'headNodeId': [],
#   'childNodeId': [],
#   'internalData': {'key': 'thinking',
#    'valueHolder': 'World',
#    'method': 'int'}}}

# %%
def generate_code(node_system):
    code = ""
    global_variables = {}

    # Generate global variables
    for node_id, node_data in node_system.items():
        node_type = node_data['type']

        if node_type == 'globalVariable':
            key = node_data['internalData']['key']
            value = node_data['internalData']['valueHolder']
            global_variables[key] = value

    # Generate code logic
    fb_output = None
    for node_id, node_data in node_system.items():
        node_type = node_data['type']

        if node_type == 'fbWebhook':
            code += f"fb_output = fbWebhook()\n"

        elif node_type == 'llmGenerate':
            system_prompt = node_data['internalData']['systemPrompt']
            user_prompt = node_data['internalData']['userPrompt']
            code += f"llm_output = llmGenerate('{system_prompt}', '{user_prompt}', fb_output)\n"

    # Add global variables to the beginning of the code
    global_code = ""
    for key, value in global_variables.items():
        global_code += f"{key} = '{value}'\n"
    code = global_code + "\n" + code

    return code

code = generate_code(node_system_output)

# Save the code to a file
with open('output.py', 'w') as file:
    file.write(code)
