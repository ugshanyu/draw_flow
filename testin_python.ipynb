# %%
y = {
  "drawflow": {
    "Home": {
      "data": {
        "7": {
          "id": 7,
          "name": "add",
          "data": {},
          "class": "add",
          "html": "add",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": [
                {
                  "node": "8",
                  "input": "output_1"
                }
              ]
            },
            "input_2": {
              "connections": [
                {
                  "node": "9",
                  "input": "output_1"
                }
              ]
            }
          },
          "outputs": {
            "output_1": {
              "connections": []
            }
          },
          "pos_x": 408,
          "pos_y": 125
        },
        "8": {
          "id": 8,
          "name": "input",
          "data": {},
          "class": "input",
          "html": "input",
          "typenode": "vue",
          "inputs": {},
          "outputs": {
            "output_1": {
              "connections": [
                {
                  "node": "7",
                  "output": "input_1"
                }
              ]
            }
          },
          "pos_x": -212.5,
          "pos_y": 42
        },
        "9": {
          "id": 9,
          "name": "input",
          "data": {},
          "class": "input",
          "html": "input",
          "typenode": "vue",
          "inputs": {},
          "outputs": {
            "output_1": {
              "connections": [
                {
                  "node": "7",
                  "output": "input_2"
                }
              ]
            }
          },
          "pos_x": -205,
          "pos_y": 220
        }
      }
    }
  }
}

# %%
def add(input_1, input_2):
    return input_1 + input_2

def run_graph(data):
    nodes = data['drawflow']['Home']['data']
    outputs = {}

    # First, simulate input nodes
    for node_id, node_info in nodes.items():
        if node_info['name'] == 'input':
            # Simulating an input node by assigning a static value
            outputs[node_id] = 5  # Modify to dynamic if necessary

    # Next, execute other nodes
    for node_id, node_info in nodes.items():
        if node_info['name'] == 'add':
            inputs = []
            for input_key, input_value in node_info['inputs'].items():
                # Assuming there's only one connection per input
                source_node = input_value['connections'][0]['node']
                inputs.append(outputs[source_node])
            outputs[node_id] = add(*inputs)

    # Output the results from all nodes
    for node_id, output in outputs.items():
        print(f"Node {node_id} output: {output}")

# %%
run_graph(y)
# Out:
# Node 8 output: 5
# Node 9 output: 5
# Node 7 output: 10

# %%
def generate_python_code(data):
    code = ""

    for module_name, module_data in data["drawflow"].items():
        code += f"# Module: {module_name}\n\n"

        for node_id, node_data in module_data["data"].items():
            node_type = node_data["class"]

            if node_type == "variable":
                variable_key = node_data["data"].get("key", "")
                variable_value = node_data["data"].get("value", "")
                variable_type = node_data["data"].get("type", "string")

                if variable_key and variable_value:
                    code += f"# Variable Node: {node_id}\n"
                    code += f"{variable_key} = "

                    if variable_type == "int":
                        code += f"{int(variable_value)}\n\n"
                    elif variable_type == "boolean":
                        code += f"{variable_value.lower() == 'true'}\n\n"
                    else:
                        code += f'"{variable_value}"\n\n'
                else:
                    code += f"# Variable Node: {node_id}\n"
                    code += "# TODO: Add variable declaration and assignment\n\n"
            # Add more conditions for other node types and generate the corresponding code

    return code

# Example usage
data = {
  "drawflow": {
    "Home": {
      "data": {
        "10": {
          "id": 10,
          "name": "variable",
          "data": {},
          "class": "variable",
          "html": "variable",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": []
            }
          },
          "outputs": {
            "output_1": {
              "connections": []
            }
          },
          "pos_x": 717,
          "pos_y": 354
        }
      }
    }
  }
}
python_code = generate_python_code(data)
print(python_code)
# Out:
# # Module: Home
#
# # Variable Node: 10
# # TODO: Add variable declaration and assignment

# %%
def extract_multiple_data(json_data):
    # Navigate to the 'data' dictionary where multiple entries are stored
    data_entries = json_data['drawflow']['Home']['data']
    
    # List to hold the extracted data objects
    extracted_data = []

    # Loop through each entry in 'data_entries'
    for key, entry in data_entries.items():
        # Extract the relevant data from each entry
        method = entry['data']['data'].get('method', '')
        valueholder = entry['data'].get('valueholder', '')
        key = entry['data'].get('key', '')

        # Append the extracted data to the list
        extracted_data.append({
            "method": method,
            "valueholder": valueholder,
            "key": key
        })

    return extracted_data

# %%
json_input = {
  "drawflow": {
    "Home": {
      "data": {
        "10": {
          "id": 10,
          "name": "variable",
          "data": {
            "id": 10,
            "name": "variable",
            "data": {
              "method": "string"
            },
            "class": "variable",
            "html": "variable",
            "typenode": "vue",
            "inputs": {
              "input_1": {
                "connections": []
              }
            },
            "outputs": {
              "output_1": {
                "connections": []
              }
            },
            "pos_x": 1153.3333129882812,
            "pos_y": 184.3333282470703,
            "valueholder": "HelloHelloHelloHelloHello",
            "key": "What is going on "
          },
          "class": "variable",
          "html": "variable",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": []
            }
          },
          "outputs": {
            "output_1": {
              "connections": []
            }
          },
          "pos_x": 441,
          "pos_y": 137
        },
        "11": {
          "id": 11,
          "name": "variable",
          "data": {
            "id": 11,
            "name": "variable",
            "data": {
              "method": "string"
            },
            "class": "variable",
            "html": "variable",
            "typenode": "vue",
            "inputs": {
              "input_1": {
                "connections": []
              }
            },
            "outputs": {
              "output_1": {
                "connections": []
              }
            },
            "pos_x": 1225.3333129882812,
            "pos_y": 319.3333282470703,
            "valueholder": "method"
          },
          "class": "variable",
          "html": "variable",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": []
            }
          },
          "outputs": {
            "output_1": {
              "connections": []
            }
          },
          "pos_x": 922,
          "pos_y": 137
        }
      }
    }
  }
}

# %%
result = extract_multiple_data(json_input)
print(result)
# Out:
# [{'method': 'string', 'valueholder': 'HelloHelloHelloHelloHello', 'key': 'What is going on '}, {'method': 'string', 'valueholder': 'method', 'key': ''}]

# %%
def extract_data(json_data):
    # Navigate to the 'data' dictionary where the nodes are stored
    nodes = json_data['drawflow']['Home']['data']
    
    # List to hold the extracted data objects
    results = []

    # Loop through each node and extract the required information
    for node_key, node in nodes.items():
        # Check if the node class is 'variable'
        if node['class'].lower() == 'variable':
            node_data = node['data']
            # Navigate deeper into the nested 'data' dictionary to extract the values
            if 'data' in node_data:
                method = node_data['data'].get('method', '')
                valueholder = node_data['data'].get('valueHolder', '')  # Notice the capital 'H'
                key = node_data['data'].get('key', '')
                results.append({
                    "method": method,
                    "valueholder": valueholder,
                    "key": key
                })

    return results

# Example JSON input
json_input = {
  "drawflow": {
    "Home": {
      "data": {
        "10": {
          "id": 10,
          "name": "llmGenerate",
          "data": {
            "id": 10,
            "name": "llmGenerate",
            "data": {
              "systemPrompt": "systemPrompt",
              "userPrompt": "This is System Prompt"
            },
            "class": "llmGenerate",
            "html": "llmGenerate",
            "typenode": "vue",
            "inputs": {
              "input_1": {
                "connections": []
              }
            },
            "outputs": {
              "output_1": {
                "connections": []
              }
            },
            "pos_x": 446,
            "pos_y": 326
          },
          "class": "llmGenerate",
          "html": "llmGenerate",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": []
            }
          },
          "outputs": {
            "output_1": {
              "connections": []
            }
          },
          "pos_x": 451,
          "pos_y": 331
        },
        "11": {
          "id": 11,
          "name": "variable",
          "data": {
            "id": 11,
            "name": "variable",
            "data": {
              "key": "systemPrompt ",
              "valueHolder": "This is System Prompt",
              "method": "string"
            },
            "class": "variable",
            "html": "variable",
            "typenode": "vue",
            "inputs": {
              "input_1": {
                "connections": []
              }
            },
            "outputs": {
              "output_1": {
                "connections": []
              }
            },
            "pos_x": 534.3333129882812,
            "pos_y": 169.3333282470703,
            "key": "systemPrompt ",
            "valueholder": "This is System Prompt"
          },
          "class": "variable",
          "html": "variable",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": []
            }
          },
          "outputs": {
            "output_1": {
              "connections": []
            }
          },
          "pos_x": 452,
          "pos_y": 20
        }
      }
    }
  }
}

# Calling the function with the updated JSON input
extracted_list = extract_data(json_input)
print(extracted_list)
# Out:
# [{'method': 'string', 'valueholder': 'This is System Prompt', 'key': 'systemPrompt '}]

# %%
def handle_variable(node_data):
    # Handle the 'variable' type node
    if 'data' in node_data:
        method = node_data['data'].get('method', '')
        valueholder = node_data['data'].get('valueHolder', '')
        key = node_data['data'].get('key', '')
        return {
            "method": method,
            "valueholder": valueholder,
            "key": key
        }

def handle_llmGenerate(node_data):
    # Handle the 'llmGenerate' type node
    if 'data' in node_data:
        system_prompt = node_data['data'].get('systemPrompt', '')
        user_prompt = node_data['data'].get('userPrompt', '')
        return {
            "systemPrompt": system_prompt,
            "userPrompt": user_prompt
        }

def process_nodes(json_data):
    nodes = json_data['drawflow']['Home']['data']
    results = []

    # Define a dispatcher dictionary to call the right function based on the class type
    dispatcher = {
        'variable': handle_variable,
        'llmgenerate': handle_llmGenerate  # Use lowercase keys for case-insensitive matching
    }

    for node_key, node in nodes.items():
        node_class = node['class'].lower()  # Convert class to lowercase to match dispatcher keys
        if node_class in dispatcher:
            # Call the appropriate function based on the node class
            result = dispatcher[node_class](node['data'])  # Pass the correct part of the node to the handler
            if result:
                results.append(result)

    return results


# Example usage:
extracted_list = process_nodes(json_input)
print(extracted_list)
# Out:
# [{'systemPrompt': 'systemPrompt', 'userPrompt': 'This is System Prompt'}, {'method': 'string', 'valueholder': 'This is System Prompt', 'key': 'systemPrompt '}]

# %%
json_input = {
  "drawflow": {
    "Home": {
      "data": {
        "10": {
          "id": 10,
          "name": "llmGenerate",
          "data": {
            "id": 10,
            "name": "llmGenerate",
            "data": {
              "systemPrompt": "systemPrompt",
              "userPrompt": "This is System Prompt"
            },
            "class": "llmGenerate",
            "html": "llmGenerate",
            "typenode": "vue",
            "inputs": {
              "input_1": {
                "connections": []
              }
            },
            "outputs": {
              "output_1": {
                "connections": []
              }
            },
            "pos_x": 446,
            "pos_y": 326
          },
          "class": "llmGenerate",
          "html": "llmGenerate",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": [
                {
                  "node": "12",
                  "input": "output_1"
                }
              ]
            }
          },
          "outputs": {
            "output_1": {
              "connections": []
            }
          },
          "pos_x": 561,
          "pos_y": 440
        },
        "12": {
          "id": 12,
          "name": "fbWebhook",
          "data": {},
          "class": "fbWebhook",
          "html": "fbWebhook",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": []
            }
          },
          "outputs": {
            "output_1": {
              "connections": [
                {
                  "node": "10",
                  "output": "input_1"
                }
              ]
            }
          },
          "pos_x": 144,
          "pos_y": 483
        }
      }
    }
  }
}

# %%
def create_node_system(json_data):
    nodes = json_data['drawflow']['Home']['data']
    node_system = {}

    for node_id, node_info in nodes.items():
        # Initialize the node system dictionary for each node
        node_system[node_id] = {
            "type": node_info['class'],
            "headNodeId": [],
            "childNodeId": [],
            "internalData": node_info['data']
        }

    # Populate headNodeId and childNodeId based on connections
    for node_id, node_info in nodes.items():
        # Handle outputs to determine child nodes
        if 'outputs' in node_info:
            for output_key, output_value in node_info['outputs'].items():
                for connection in output_value['connections']:
                    child_node_id = connection['node']
                    node_system[node_id]['childNodeId'].append(child_node_id)
                    # Also update the head node information for the connected node
                    if node_id not in node_system[child_node_id]['headNodeId']:
                        node_system[child_node_id]['headNodeId'].append(node_id)

    return node_system

# Example usage:
node_system_output = create_node_system(json_input)
print(node_system_output)
# Out:
# {'10': {'type': 'llmGenerate', 'headNodeId': ['12'], 'childNodeId': [], 'internalData': {'id': 10, 'name': 'llmGenerate', 'data': {'systemPrompt': 'systemPrompt', 'userPrompt': 'This is System Prompt'}, 'class': 'llmGenerate', 'html': 'llmGenerate', 'typenode': 'vue', 'inputs': {'input_1': {'connections': []}}, 'outputs': {'output_1': {'connections': []}}, 'pos_x': 446, 'pos_y': 326}}, '12': {'type': 'fbWebhook', 'headNodeId': [], 'childNodeId': ['10'], 'internalData': {}}}

# %%
node_system_output["10"]
# Out:
# {'type': 'llmGenerate',
#  'headNodeId': ['12'],
#  'childNodeId': [],
#  'internalData': {'id': 10,
#   'name': 'llmGenerate',
#   'data': {'systemPrompt': 'systemPrompt',
#    'userPrompt': 'This is System Prompt'},
#   'class': 'llmGenerate',
#   'html': 'llmGenerate',
#   'typenode': 'vue',
#   'inputs': {'input_1': {'connections': []}},
#   'outputs': {'output_1': {'connections': []}},
#   'pos_x': 446,
#   'pos_y': 326}}

# %%
node_system_output["12"]
# Out:
# {'type': 'fbWebhook',
#  'headNodeId': [],
#  'childNodeId': ['10'],
#  'internalData': {}}

# %%
json_input = {
  "drawflow": {
    "Home": {
      "data": {
        "10": {
          "id": 10,
          "name": "llmGenerate",
          "data": {
            "id": 10,
            "name": "llmGenerate",
            "data": {
              "systemPrompt": "2",
              "userPrompt": "3"
            },
            "class": "llmGenerate",
            "html": "llmGenerate",
            "typenode": "vue",
            "inputs": {
              "input_1": {
                "connections": []
              }
            },
            "outputs": {
              "output_1": {
                "connections": [
                  {
                    "node": "11",
                    "output": "input_1"
                  }
                ]
              }
            },
            "pos_x": 600,
            "pos_y": 503
          },
          "class": "llmGenerate",
          "html": "llmGenerate",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": []
            }
          },
          "outputs": {
            "output_1": {
              "connections": [
                {
                  "node": "20",
                  "output": "input_1"
                }
              ]
            }
          },
          "pos_x": 490.5,
          "pos_y": 500.75
        },
        "18": {
          "id": 18,
          "name": "globalVariable",
          "data": {
            "id": 18,
            "name": "globalVariable",
            "data": {
              "key": "World",
              "valueHolder": "MINE",
              "method": "string"
            },
            "class": "globalVariable",
            "html": "globalVariable",
            "typenode": "vue",
            "inputs": {},
            "outputs": {},
            "pos_x": 793.6666564941406,
            "pos_y": 244.66666412353516,
            "key": "World",
            "valueholder": "MINE"
          },
          "class": "globalVariable",
          "html": "globalVariable",
          "typenode": "vue",
          "inputs": {},
          "outputs": {},
          "pos_x": 489.75,
          "pos_y": 119
        },
        "20": {
          "id": 20,
          "name": "extractOutput",
          "data": {},
          "class": "extractOutput",
          "html": "extractOutput",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": [
                {
                  "node": "10",
                  "input": "output_1"
                }
              ]
            }
          },
          "outputs": {
            "output_1": {
              "connections": [
                {
                  "node": "21",
                  "output": "input_1"
                }
              ]
            }
          },
          "pos_x": 845.25,
          "pos_y": 547
        },
        "21": {
          "id": 21,
          "name": "switch",
          "data": {},
          "class": "switch",
          "html": "switch",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": [
                {
                  "node": "20",
                  "input": "output_1"
                }
              ]
            }
          },
          "outputs": {
            "output_1": {
              "connections": [
                {
                  "node": "23",
                  "output": "input_1"
                },
                {
                  "node": "26",
                  "output": "input_1"
                },
                {
                  "node": "27",
                  "output": "input_1"
                }
              ]
            }
          },
          "pos_x": 1185,
          "pos_y": 547.25
        },
        "23": {
          "id": 23,
          "name": "switchCase",
          "data": {},
          "class": "switchCase",
          "html": "switchCase",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": [
                {
                  "node": "21",
                  "input": "output_1"
                }
              ]
            }
          },
          "outputs": {
            "output_1": {
              "connections": []
            }
          },
          "pos_x": 1481.5,
          "pos_y": 291
        },
        "26": {
          "id": 26,
          "name": "switchCase",
          "data": {},
          "class": "switchCase",
          "html": "switchCase",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": [
                {
                  "node": "21",
                  "input": "output_1"
                }
              ]
            }
          },
          "outputs": {
            "output_1": {
              "connections": []
            }
          },
          "pos_x": 1503.75,
          "pos_y": 524
        },
        "27": {
          "id": 27,
          "name": "switchCase",
          "data": {},
          "class": "switchCase",
          "html": "switchCase",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": [
                {
                  "node": "21",
                  "input": "output_1"
                }
              ]
            }
          },
          "outputs": {
            "output_1": {
              "connections": []
            }
          },
          "pos_x": 1469.75,
          "pos_y": 780
        }
      }
    }
  }
}

# %%
json_input = {
  "drawflow": {
    "Home": {
      "data": {
        "10": {
          "id": 10,
          "name": "variableSet",
          "data": {
            "id": 10,
            "name": "variableSet",
            "data": {
              "key": "userMessage"
            },
            "class": "variableSet",
            "html": "variableSet",
            "typenode": "vue",
            "inputs": {
              "input_1": {
                "connections": []
              }
            },
            "outputs": {
              "output_1": {
                "connections": []
              }
            },
            "pos_x": 772,
            "pos_y": 654,
            "key": "userMessage"
          },
          "class": "variableSet",
          "html": "variableSet",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": [
                {
                  "node": "11",
                  "input": "output_1"
                }
              ]
            }
          },
          "outputs": {
            "output_1": {
              "connections": [
                {
                  "node": "12",
                  "output": "input_1"
                }
              ]
            }
          },
          "pos_x": -267.25,
          "pos_y": 381
        },
        "11": {
          "id": 11,
          "name": "fbWebhook",
          "data": {},
          "class": "fbWebhook",
          "html": "fbWebhook",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": []
            }
          },
          "outputs": {
            "output_1": {
              "connections": [
                {
                  "node": "10",
                  "output": "input_1"
                }
              ]
            }
          },
          "pos_x": -635.25,
          "pos_y": 402
        },
        "12": {
          "id": 12,
          "name": "llmGenerate",
          "data": {
            "id": 12,
            "name": "llmGenerate",
            "data": {
              "systemPrompt": "Test",
              "userPrompt": "WE + \"  \\nNow User Says \" + userMessage"
            },
            "class": "llmGenerate",
            "html": "llmGenerate",
            "typenode": "vue",
            "inputs": {
              "input_1": {
                "connections": [
                  {
                    "node": "10",
                    "input": "output_1"
                  }
                ]
              }
            },
            "outputs": {
              "output_1": {
                "connections": [
                  {
                    "node": "13",
                    "output": "input_1"
                  }
                ]
              }
            },
            "pos_x": 95.75,
            "pos_y": 352.75
          },
          "class": "llmGenerate",
          "html": "llmGenerate",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": [
                {
                  "node": "10",
                  "input": "output_1"
                }
              ]
            }
          },
          "outputs": {
            "output_1": {
              "connections": [
                {
                  "node": "13",
                  "output": "input_1"
                }
              ]
            }
          },
          "pos_x": 95.75,
          "pos_y": 352.75
        },
        "13": {
          "id": 13,
          "name": "extractOutput",
          "data": {},
          "class": "extractOutput",
          "html": "extractOutput",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": [
                {
                  "node": "12",
                  "input": "output_1"
                }
              ]
            }
          },
          "outputs": {
            "output_1": {
              "connections": [
                {
                  "node": "14",
                  "output": "input_1"
                }
              ]
            }
          },
          "pos_x": 483,
          "pos_y": 400
        },
        "14": {
          "id": 14,
          "name": "switch",
          "data": {},
          "class": "switch",
          "html": "switch",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": [
                {
                  "node": "13",
                  "input": "output_1"
                }
              ]
            }
          },
          "outputs": {
            "output_1": {
              "connections": [
                {
                  "node": "15",
                  "output": "input_1"
                },
                {
                  "node": "16",
                  "output": "input_1"
                },
                {
                  "node": "17",
                  "output": "input_1"
                }
              ]
            }
          },
          "pos_x": 893,
          "pos_y": 396
        },
        "15": {
          "id": 15,
          "name": "switchCase",
          "data": {
            "id": 15,
            "name": "switchCase",
            "data": {
              "input": "Case1"
            },
            "class": "switchCase",
            "html": "switchCase",
            "typenode": "vue",
            "inputs": {
              "input_1": {
                "connections": [
                  {
                    "node": "14",
                    "input": "output_1"
                  }
                ]
              }
            },
            "outputs": {
              "output_1": {
                "connections": [
                  {
                    "node": "18",
                    "output": "input_1"
                  }
                ]
              }
            },
            "pos_x": 1305,
            "pos_y": 130
          },
          "class": "switchCase",
          "html": "switchCase",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": [
                {
                  "node": "14",
                  "input": "output_1"
                }
              ]
            }
          },
          "outputs": {
            "output_1": {
              "connections": [
                {
                  "node": "18",
                  "output": "input_1"
                }
              ]
            }
          },
          "pos_x": 1305,
          "pos_y": 130
        },
        "16": {
          "id": 16,
          "name": "switchCase",
          "data": {
            "id": 16,
            "name": "switchCase",
            "data": {
              "input": "Case2"
            },
            "class": "switchCase",
            "html": "switchCase",
            "typenode": "vue",
            "inputs": {
              "input_1": {
                "connections": [
                  {
                    "node": "14",
                    "input": "output_1"
                  }
                ]
              }
            },
            "outputs": {
              "output_1": {
                "connections": [
                  {
                    "node": "22",
                    "output": "input_1"
                  }
                ]
              }
            },
            "pos_x": 1313,
            "pos_y": 362
          },
          "class": "switchCase",
          "html": "switchCase",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": [
                {
                  "node": "14",
                  "input": "output_1"
                }
              ]
            }
          },
          "outputs": {
            "output_1": {
              "connections": [
                {
                  "node": "22",
                  "output": "input_1"
                }
              ]
            }
          },
          "pos_x": 1313,
          "pos_y": 362
        },
        "17": {
          "id": 17,
          "name": "switchCase",
          "data": {
            "id": 17,
            "name": "switchCase",
            "data": {
              "input": "Case3"
            },
            "class": "switchCase",
            "html": "switchCase",
            "typenode": "vue",
            "inputs": {
              "input_1": {
                "connections": [
                  {
                    "node": "14",
                    "input": "output_1"
                  }
                ]
              }
            },
            "outputs": {
              "output_1": {
                "connections": [
                  {
                    "node": "19",
                    "output": "input_1"
                  }
                ]
              }
            },
            "pos_x": 1311,
            "pos_y": 606
          },
          "class": "switchCase",
          "html": "switchCase",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": [
                {
                  "node": "14",
                  "input": "output_1"
                }
              ]
            }
          },
          "outputs": {
            "output_1": {
              "connections": [
                {
                  "node": "19",
                  "output": "input_1"
                }
              ]
            }
          },
          "pos_x": 1311,
          "pos_y": 606
        },
        "18": {
          "id": 18,
          "name": "llmGenerate",
          "data": {
            "id": 18,
            "name": "llmGenerate",
            "data": {
              "systemPrompt": "12",
              "userPrompt": "23"
            },
            "class": "llmGenerate",
            "html": "llmGenerate",
            "typenode": "vue",
            "inputs": {
              "input_1": {
                "connections": [
                  {
                    "node": "15",
                    "input": "output_1"
                  }
                ]
              }
            },
            "outputs": {
              "output_1": {
                "connections": []
              }
            },
            "pos_x": 1712.5,
            "pos_y": 104
          },
          "class": "llmGenerate",
          "html": "llmGenerate",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": [
                {
                  "node": "15",
                  "input": "output_1"
                }
              ]
            }
          },
          "outputs": {
            "output_1": {
              "connections": []
            }
          },
          "pos_x": 1712.5,
          "pos_y": 104
        },
        "19": {
          "id": 19,
          "name": "llmGenerate",
          "data": {
            "id": 19,
            "name": "llmGenerate",
            "data": {
              "systemPrompt": "123",
              "userPrompt": "123"
            },
            "class": "llmGenerate",
            "html": "llmGenerate",
            "typenode": "vue",
            "inputs": {
              "input_1": {
                "connections": [
                  {
                    "node": "17",
                    "input": "output_1"
                  }
                ]
              }
            },
            "outputs": {
              "output_1": {
                "connections": []
              }
            },
            "pos_x": 1714.75,
            "pos_y": 584.25
          },
          "class": "llmGenerate",
          "html": "llmGenerate",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": [
                {
                  "node": "17",
                  "input": "output_1"
                }
              ]
            }
          },
          "outputs": {
            "output_1": {
              "connections": []
            }
          },
          "pos_x": 1714.75,
          "pos_y": 584.25
        },
        "22": {
          "id": 22,
          "name": "variableSet",
          "data": {
            "id": 22,
            "name": "variableSet",
            "data": {
              "key": "Test"
            },
            "class": "variableSet",
            "html": "variableSet",
            "typenode": "vue",
            "inputs": {
              "input_1": {
                "connections": []
              }
            },
            "outputs": {
              "output_1": {
                "connections": []
              }
            },
            "pos_x": 1948.0000305175781,
            "pos_y": 455.25001525878906,
            "key": "Test"
          },
          "class": "variableSet",
          "html": "variableSet",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": [
                {
                  "node": "16",
                  "input": "output_1"
                }
              ]
            }
          },
          "outputs": {
            "output_1": {
              "connections": [
                {
                  "node": "23",
                  "output": "input_1"
                }
              ]
            }
          },
          "pos_x": 1711.75,
          "pos_y": 364
        },
        "23": {
          "id": 23,
          "name": "llmGenerate",
          "data": {
            "id": 23,
            "name": "llmGenerate",
            "data": {
              "systemPrompt": "432",
              "userPrompt": "5345345"
            },
            "class": "llmGenerate",
            "html": "llmGenerate",
            "typenode": "vue",
            "inputs": {
              "input_1": {
                "connections": [
                  {
                    "node": "22",
                    "input": "output_1"
                  }
                ]
              }
            },
            "outputs": {
              "output_1": {
                "connections": [
                  {
                    "node": "24",
                    "output": "input_1"
                  }
                ]
              }
            },
            "pos_x": 2120.5,
            "pos_y": 340
          },
          "class": "llmGenerate",
          "html": "llmGenerate",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": [
                {
                  "node": "22",
                  "input": "output_1"
                }
              ]
            }
          },
          "outputs": {
            "output_1": {
              "connections": [
                {
                  "node": "24",
                  "output": "input_1"
                }
              ]
            }
          },
          "pos_x": 2120.5,
          "pos_y": 340
        },
        "24": {
          "id": 24,
          "name": "extractOutput",
          "data": {},
          "class": "extractOutput",
          "html": "extractOutput",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": [
                {
                  "node": "23",
                  "input": "output_1"
                }
              ]
            }
          },
          "outputs": {
            "output_1": {
              "connections": [
                {
                  "node": "25",
                  "output": "input_1"
                }
              ]
            }
          },
          "pos_x": 2505,
          "pos_y": 389.5
        },
        "25": {
          "id": 25,
          "name": "switch",
          "data": {},
          "class": "switch",
          "html": "switch",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": [
                {
                  "node": "24",
                  "input": "output_1"
                }
              ]
            }
          },
          "outputs": {
            "output_1": {
              "connections": [
                {
                  "node": "26",
                  "output": "input_1"
                },
                {
                  "node": "27",
                  "output": "input_1"
                }
              ]
            }
          },
          "pos_x": 2892.75,
          "pos_y": 388
        },
        "26": {
          "id": 26,
          "name": "switchCase",
          "data": {
            "id": 26,
            "name": "switchCase",
            "data": {
              "input": "fqw"
            },
            "class": "switchCase",
            "html": "switchCase",
            "typenode": "vue",
            "inputs": {
              "input_1": {
                "connections": [
                  {
                    "node": "25",
                    "input": "output_1"
                  }
                ]
              }
            },
            "outputs": {
              "output_1": {
                "connections": [
                  {
                    "node": "28",
                    "output": "input_1"
                  }
                ]
              }
            },
            "pos_x": 3295.75,
            "pos_y": 180.75
          },
          "class": "switchCase",
          "html": "switchCase",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": [
                {
                  "node": "25",
                  "input": "output_1"
                }
              ]
            }
          },
          "outputs": {
            "output_1": {
              "connections": [
                {
                  "node": "28",
                  "output": "input_1"
                }
              ]
            }
          },
          "pos_x": 3295.75,
          "pos_y": 180.75
        },
        "27": {
          "id": 27,
          "name": "switchCase",
          "data": {
            "id": 27,
            "name": "switchCase",
            "data": {
              "input": "qwefqw"
            },
            "class": "switchCase",
            "html": "switchCase",
            "typenode": "vue",
            "inputs": {
              "input_1": {
                "connections": [
                  {
                    "node": "25",
                    "input": "output_1"
                  }
                ]
              }
            },
            "outputs": {
              "output_1": {
                "connections": [
                  {
                    "node": "29",
                    "output": "input_1"
                  }
                ]
              }
            },
            "pos_x": 3316.75,
            "pos_y": 548
          },
          "class": "switchCase",
          "html": "switchCase",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": [
                {
                  "node": "25",
                  "input": "output_1"
                }
              ]
            }
          },
          "outputs": {
            "output_1": {
              "connections": [
                {
                  "node": "29",
                  "output": "input_1"
                }
              ]
            }
          },
          "pos_x": 3316.75,
          "pos_y": 548
        },
        "28": {
          "id": 28,
          "name": "llmGenerate",
          "data": {
            "id": 28,
            "name": "llmGenerate",
            "data": {
              "systemPrompt": "sdvsdv",
              "userPrompt": "sdfvsdfv"
            },
            "class": "llmGenerate",
            "html": "llmGenerate",
            "typenode": "vue",
            "inputs": {
              "input_1": {
                "connections": [
                  {
                    "node": "26",
                    "input": "output_1"
                  }
                ]
              }
            },
            "outputs": {
              "output_1": {
                "connections": []
              }
            },
            "pos_x": 3765,
            "pos_y": 150.75
          },
          "class": "llmGenerate",
          "html": "llmGenerate",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": [
                {
                  "node": "26",
                  "input": "output_1"
                }
              ]
            }
          },
          "outputs": {
            "output_1": {
              "connections": []
            }
          },
          "pos_x": 3765,
          "pos_y": 150.75
        },
        "29": {
          "id": 29,
          "name": "llmGenerate",
          "data": {
            "id": 29,
            "name": "llmGenerate",
            "data": {
              "systemPrompt": "rterthrteh",
              "userPrompt": "jrrtytytj"
            },
            "class": "llmGenerate",
            "html": "llmGenerate",
            "typenode": "vue",
            "inputs": {
              "input_1": {
                "connections": [
                  {
                    "node": "27",
                    "input": "output_1"
                  }
                ]
              }
            },
            "outputs": {
              "output_1": {
                "connections": []
              }
            },
            "pos_x": 3765.75,
            "pos_y": 518
          },
          "class": "llmGenerate",
          "html": "llmGenerate",
          "typenode": "vue",
          "inputs": {
            "input_1": {
              "connections": [
                {
                  "node": "27",
                  "input": "output_1"
                }
              ]
            }
          },
          "outputs": {
            "output_1": {
              "connections": []
            }
          },
          "pos_x": 3765.75,
          "pos_y": 518
        }
      }
    }
  }
}

# %%
def create_node_system(json_data):
    nodes = json_data['drawflow']['Home']['data']
    node_system = {}

    for node_id, node_info in nodes.items():
        # Initialize the node system dictionary for each node
        # Ensure internalData points to the innermost 'data' dictionary if it exists
        internal_data = node_info['data']['data'] if 'data' in node_info['data'] else {}
        node_system[node_id] = {
            "type": node_info['class'],
            "headNodeId": [],
            "childNodeId": [],
            "internalData": internal_data
        }

    # Populate headNodeId and childNodeId based on connections
    for node_id, node_info in nodes.items():
        # Handle outputs to determine child nodes
        if 'outputs' in node_info:
            for output_key, output_value in node_info['outputs'].items():
                for connection in output_value['connections']:
                    child_node_id = connection['node']
                    node_system[node_id]['childNodeId'].append(child_node_id)
                    # Also update the head node information for the connected node
                    if node_id not in node_system[child_node_id]['headNodeId']:
                        node_system[child_node_id]['headNodeId'].append(node_id)

    return node_system

# Example usage:
node_system_output = create_node_system(json_input)
print(node_system_output)
# Out:
# {'10': {'type': 'variableSet', 'headNodeId': ['11'], 'childNodeId': ['12'], 'internalData': {'key': 'userMessage'}}, '11': {'type': 'fbWebhook', 'headNodeId': [], 'childNodeId': ['10'], 'internalData': {}}, '12': {'type': 'llmGenerate', 'headNodeId': ['10'], 'childNodeId': ['13'], 'internalData': {'systemPrompt': 'Test', 'userPrompt': 'WE + "  \\nNow User Says " + userMessage'}}, '13': {'type': 'extractOutput', 'headNodeId': ['12'], 'childNodeId': ['14'], 'internalData': {}}, '14': {'type': 'switch', 'headNodeId': ['13'], 'childNodeId': ['15', '16', '17'], 'internalData': {}}, '15': {'type': 'switchCase', 'headNodeId': ['14'], 'childNodeId': ['18'], 'internalData': {'input': 'Case1'}}, '16': {'type': 'switchCase', 'headNodeId': ['14'], 'childNodeId': ['22'], 'internalData': {'input': 'Case2'}}, '17': {'type': 'switchCase', 'headNodeId': ['14'], 'childNodeId': ['19'], 'internalData': {'input': 'Case3'}}, '18': {'type': 'llmGenerate', 'headNodeId': ['15'], 'childNodeId': [], 'internalData': {'systemPrompt': '12', 'userPrompt': '23'}}, '19': {'type': 'llmGenerate', 'headNodeId': ['17'], 'childNodeId': [], 'internalData': {'systemPrompt': '123', 'userPrompt': '123'}}, '22': {'type': 'variableSet', 'headNodeId': ['16'], 'childNodeId': ['23'], 'internalData': {'key': 'Test'}}, '23': {'type': 'llmGenerate', 'headNodeId': ['22'], 'childNodeId': ['24'], 'internalData': {'systemPrompt': '432', 'userPrompt': '5345345'}}, '24': {'type': 'extractOutput', 'headNodeId': ['23'], 'childNodeId': ['25'], 'internalData': {}}, '25': {'type': 'switch', 'headNodeId': ['24'], 'childNodeId': ['26', '27'], 'internalData': {}}, '26': {'type': 'switchCase', 'headNodeId': ['25'], 'childNodeId': ['28'], 'internalData': {'input': 'fqw'}}, '27': {'type': 'switchCase', 'headNodeId': ['25'], 'childNodeId': ['29'], 'internalData': {'input': 'qwefqw'}}, '28': {'type': 'llmGenerate', 'headNodeId': ['26'], 'childNodeId': [], 'internalData': {'systemPrompt': 'sdvsdv', 'userPrompt': 'sdfvsdfv'}}, '29': {'type': 'llmGenerate', 'headNodeId': ['27'], 'childNodeId': [], 'internalData': {'systemPrompt': 'rterthrteh', 'userPrompt': 'jrrtytytj'}}}

# %%
node_system_output
# Out:
# {'10': {'type': 'variableSet',
#   'headNodeId': ['11'],
#   'childNodeId': ['12'],
#   'internalData': {'key': 'userMessage'}},
#  '11': {'type': 'fbWebhook',
#   'headNodeId': [],
#   'childNodeId': ['10'],
#   'internalData': {}},
#  '12': {'type': 'llmGenerate',
#   'headNodeId': ['10'],
#   'childNodeId': ['13'],
#   'internalData': {'systemPrompt': 'Test',
#    'userPrompt': 'WE + "  \\nNow User Says " + userMessage'}},
#  '13': {'type': 'extractOutput',
#   'headNodeId': ['12'],
#   'childNodeId': ['14'],
#   'internalData': {}},
#  '14': {'type': 'switch',
#   'headNodeId': ['13'],
#   'childNodeId': ['15', '16', '17'],
#   'internalData': {}},
#  '15': {'type': 'switchCase',
#   'headNodeId': ['14'],
#   'childNodeId': ['18'],
#   'internalData': {'input': 'Case1'}},
#  '16': {'type': 'switchCase',
#   'headNodeId': ['14'],
#   'childNodeId': ['22'],
#   'internalData': {'input': 'Case2'}},
#  '17': {'type': 'switchCase',
#   'headNodeId': ['14'],
#   'childNodeId': ['19'],
#   'internalData': {'input': 'Case3'}},
#  '18': {'type': 'llmGenerate',
#   'headNodeId': ['15'],
#   'childNodeId': [],
#   'internalData': {'systemPrompt': '12', 'userPrompt': '23'}},
#  '19': {'type': 'llmGenerate',
#   'headNodeId': ['17'],
#   'childNodeId': [],
#   'internalData': {'systemPrompt': '123', 'userPrompt': '123'}},
#  '22': {'type': 'variableSet',
#   'headNodeId': ['16'],
#   'childNodeId': ['23'],
#   'internalData': {'key': 'Test'}},
#  '23': {'type': 'llmGenerate',
#   'headNodeId': ['22'],
#   'childNodeId': ['24'],
#   'internalData': {'systemPrompt': '432', 'userPrompt': '5345345'}},
#  '24': {'type': 'extractOutput',
#   'headNodeId': ['23'],
#   'childNodeId': ['25'],
#   'internalData': {}},
#  '25': {'type': 'switch',
#   'headNodeId': ['24'],
#   'childNodeId': ['26', '27'],
#   'internalData': {}},
#  '26': {'type': 'switchCase',
#   'headNodeId': ['25'],
#   'childNodeId': ['28'],
#   'internalData': {'input': 'fqw'}},
#  '27': {'type': 'switchCase',
#   'headNodeId': ['25'],
#   'childNodeId': ['29'],
#   'internalData': {'input': 'qwefqw'}},
#  '28': {'type': 'llmGenerate',
#   'headNodeId': ['26'],
#   'childNodeId': [],
#   'internalData': {'systemPrompt': 'sdvsdv', 'userPrompt': 'sdfvsdfv'}},
#  '29': {'type': 'llmGenerate',
#   'headNodeId': ['27'],
#   'childNodeId': [],
#   'internalData': {'systemPrompt': 'rterthrteh', 'userPrompt': 'jrrtytytj'}}}

# %%
import json

def generate_code(node_system):
    code = []  # Initialize code as an empty list
    global_variables = {}

    # Extract global variables
    for node_id, node_data in node_system.items():
        if node_data['type'] == 'globalVariable':
            key = node_data['internalData']['key']
            value = node_data['internalData']['valueHolder']
            method = node_data['internalData']['method']
            global_variables[key] = (value, method)

    # Generate global variable assignments
    for key, (value, method) in global_variables.items():
        if method == 'string':
            code.append(f"{key} = '{value}'\n")
        else:
            code.append(f"{key} = {value}\n")

    # Find the starting node
    start_node_id = None
    for node_id, node_data in node_system.items():
        if node_data['type'] == 'fbWebhook' and not node_data['headNodeId']:
            start_node_id = node_id
            break

    # Generate code for each node
    visited_nodes = set()
    def generate_node_code(node_id, indent="", head_node_id=None):
        if node_id in visited_nodes:
            return
        visited_nodes.add(node_id)

        node_data = node_system[node_id]
        node_type = node_data['type']

        if node_type == 'fbWebhook':
            code_line = f"{indent}fbWebhook()\n"
            code_line = f"{indent}node{node_id} = " + code_line
            code.append(code_line)
            for child_node_id in node_data['childNodeId']:
                generate_node_code(child_node_id, indent, f"node{node_id}")

        elif node_type == 'llmGenerate':
            system_prompt = node_data['internalData']['systemPrompt']
            user_prompt = node_data['internalData']['userPrompt']
            code_line = f"{indent}llmGenerate({system_prompt}, {user_prompt}, {head_node_id})\n"
            code_line = f"{indent}node{node_id} = " + code_line
            code.append(code_line)
            for child_node_id in node_data['childNodeId']:
                generate_node_code(child_node_id, indent, f"node{node_id}")

        elif node_type == 'extractOutput':
            code_line = f"{indent}extractOutput({head_node_id})\n"
            code_line = f"{indent}node{node_id} = " + code_line
            code.append(code_line)
            for child_node_id in node_data['childNodeId']:
                generate_node_code(child_node_id, indent, f"node{node_id}")

        elif node_type == 'switch':
            # print('head_node_id:', head_node_id)
            code.append(f"{indent}match {head_node_id}:\n")
            for child_node_id in node_data['childNodeId']:
                generate_node_code(child_node_id, indent + "    ", head_node_id)

        elif node_type == 'switchCase':
            input_value = node_data['internalData']['input']
            code.append(f"{indent}case '{input_value}':\n")
            for child_node_id in node_data['childNodeId']:
                generate_node_code(child_node_id, indent + "    ", head_node_id)

        elif node_type == 'variableSet':
            key = node_data['internalData']['key']
            code.append(f"{indent}{key} = {head_node_id}")
            for child_node_id in node_data['childNodeId']:
                generate_node_code(child_node_id, indent, key)

        elif node_type == 'functionWrapper':
            # print("childNodeId:", node_data['childNodeId'])
            # print("headNodeId:", node_data['headNodeId'][0])
            # code.append(f"{indent}match :\n")
            for child_node_id in node_data['childNodeId']:
                generate_node_code(child_node_id, indent, f"node{node_data['headNodeId'][0]}")

    generate_node_code(start_node_id)
    return "\n".join(code)

# Example usage
generated_code = generate_code(node_system_output)
print(generated_code)

# Write to file
# with open
# Out:
# node11 = fbWebhook()
#
# userMessage = node11
# node12 = llmGenerate(Test, WE + "  \nNow User Says " + userMessage, userMessage)
#
# node13 = extractOutput(node12)
#
# match node13:
#
#     case 'Case1':
#
#         node18 =         llmGenerate(12, 23, node13)
#
#     case 'Case2':
#
#         Test = node13
#         node23 =         llmGenerate(432, 5345345, Test)
#
#         node24 =         extractOutput(node23)
#
#         match node24:
#
#             case 'fqw':
#
#                 node28 =                 llmGenerate(sdvsdv, sdfvsdfv, node24)
#
#             case 'qwefqw':
#
#                 node29 =                 llmGenerate(rterthrteh, jrrtytytj, node24)
#
#     case 'Case3':
#
#         node19 =         llmGenerate(123, 123, node13)

# %%
node11 = fbWebhook()
userMessage = node11

# %%
import anthropic

client = anthropic.Anthropic(
    # defaults to os.environ.get("ANTHROPIC_API_KEY")
)
message = client.messages.create(
    model="claude-3-opus-20240229",
    max_tokens=2048,
    temperature=0,
    messages=[
        {
            "role": "user",
            "content": [
                {
                    "type": "text",
                    "text": """Lets implement a variableSet so that we save the it head node output to a variable of its key and we pass it to the next node as input.
                    import json

def generate_code(node_system):
    code = []  # Initialize code as an empty list
    global_variables = {}

    # Extract global variables
    for node_id, node_data in node_system.items():
        if node_data['type'] == 'globalVariable':
            key = node_data['internalData']['key']
            value = node_data['internalData']['valueHolder']
            method = node_data['internalData']['method']
            global_variables[key] = (value, method)

    # Generate global variable assignments
    for key, (value, method) in global_variables.items():
        if method == 'string':
            code.append(f"{key} = '{value}'\n")
        else:
            code.append(f"{key} = {value}\n")

    # Find the starting node
    start_node_id = None
    for node_id, node_data in node_system.items():
        if node_data['type'] == 'fbWebhook' and not node_data['headNodeId']:
            start_node_id = node_id
            break

    # Generate code for each node
    visited_nodes = set()
    def generate_node_code(node_id, indent="", head_node_id=None):
        if node_id in visited_nodes:
            return
        visited_nodes.add(node_id)

        node_data = node_system[node_id]
        node_type = node_data['type']

        if node_type == 'fbWebhook':
            code_line = f"{indent}fbWebhook()\n"
            code_line = f"{indent}node{node_id} = " + code_line
            code.append(code_line)
            for child_node_id in node_data['childNodeId']:
                generate_node_code(child_node_id, indent, f"node{node_id}")

        elif node_type == 'llmGenerate':
            system_prompt = node_data['internalData']['systemPrompt']
            user_prompt = node_data['internalData']['userPrompt']
            code_line = f"{indent}llmGenerate('{system_prompt}', '{user_prompt}', {head_node_id})\n"
            code_line = f"{indent}node{node_id} = " + code_line
            code.append(code_line)
            for child_node_id in node_data['childNodeId']:
                generate_node_code(child_node_id, indent, f"node{node_id}")

        elif node_type == 'extractOutput':
            code_line = f"{indent}extractOutput({head_node_id})\n"
            code_line = f"{indent}node{node_id} = " + code_line
            code.append(code_line)
            for child_node_id in node_data['childNodeId']:
                generate_node_code(child_node_id, indent, f"node{node_id}")

        elif node_type == 'switch':
            # print('head_node_id:', head_node_id)
            code.append(f"{indent}match {head_node_id}:\n")
            for child_node_id in node_data['childNodeId']:
                generate_node_code(child_node_id, indent + "    ", head_node_id)

        elif node_type == 'switchCase':
            input_value = node_data['internalData']['input']
            code.append(f"{indent}case '{input_value}':\n")
            for child_node_id in node_data['childNodeId']:
                generate_node_code(child_node_id, indent + "    ", head_node_id)

        elif node_type == 'variableSet':

        elif node_type == 'functionWrapper':
            # print("childNodeId:", node_data['childNodeId'])
            # print("headNodeId:", node_data['headNodeId'][0])
            # code.append(f"{indent}match :\n")
            for child_node_id in node_data['childNodeId']:
                generate_node_code(child_node_id, indent, f"node{node_data['headNodeId'][0]}")

    generate_node_code(start_node_id)
    return "\n".join(code)

# Example usage
generated_code = generate_code(node_system_output)
print(generated_code)

# Write to file
# with open
                    
                    """
                }
            ]
        }
    ]
)
print(message.content)
# Out:
# [TextBlock(text='To implement the `variableSet` node so that it saves the output of its head node to a variable with the specified key and passes it to the next node as input, you can modify the `generate_code` function as follows:\n\n```python\nimport json\n\ndef generate_code(node_system):\n    code = []  # Initialize code as an empty list\n    global_variables = {}\n\n    # Extract global variables\n    for node_id, node_data in node_system.items():\n        if node_data[\'type\'] == \'globalVariable\':\n            key = node_data[\'internalData\'][\'key\']\n            value = node_data[\'internalData\'][\'valueHolder\']\n            method = node_data[\'internalData\'][\'method\']\n            global_variables[key] = (value, method)\n\n    # Generate global variable assignments\n    for key, (value, method) in global_variables.items():\n        if method == \'string\':\n            code.append(f"{key} = \'{value}\'")\n        else:\n            code.append(f"{key} = {value}")\n\n    # Find the starting node\n    start_node_id = None\n    for node_id, node_data in node_system.items():\n        if node_data[\'type\'] == \'fbWebhook\' and not node_data[\'headNodeId\']:\n            start_node_id = node_id\n            break\n\n    # Generate code for each node\n    visited_nodes = set()\n    def generate_node_code(node_id, indent="", head_node_id=None):\n        if node_id in visited_nodes:\n            return\n        visited_nodes.add(node_id)\n\n        node_data = node_system[node_id]\n        node_type = node_data[\'type\']\n\n        if node_type == \'fbWebhook\':\n            code_line = f"{indent}fbWebhook()"\n            code_line = f"{indent}node{node_id} = " + code_line\n            code.append(code_line)\n            for child_node_id in node_data[\'childNodeId\']:\n                generate_node_code(child_node_id, indent, f"node{node_id}")\n\n        elif node_type == \'llmGenerate\':\n            system_prompt = node_data[\'internalData\'][\'systemPrompt\']\n            user_prompt = node_data[\'internalData\'][\'userPrompt\']\n            code_line = f"{indent}llmGenerate(\'{system_prompt}\', \'{user_prompt}\', {head_node_id})"\n            code_line = f"{indent}node{node_id} = " + code_line\n            code.append(code_line)\n            for child_node_id in node_data[\'childNodeId\']:\n                generate_node_code(child_node_id, indent, f"node{node_id}")\n\n        elif node_type == \'extractOutput\':\n            code_line = f"{indent}extractOutput({head_node_id})"\n            code_line = f"{indent}node{node_id} = " + code_line\n            code.append(code_line)\n            for child_node_id in node_data[\'childNodeId\']:\n                generate_node_code(child_node_id, indent, f"node{node_id}")\n\n        elif node_type == \'switch\':\n            code.append(f"{indent}match {head_node_id}:")\n            for child_node_id in node_data[\'childNodeId\']:\n                generate_node_code(child_node_id, indent + "    ", head_node_id)\n\n        elif node_type == \'switchCase\':\n            input_value = node_data[\'internalData\'][\'input\']\n            code.append(f"{indent}case \'{input_value}\':")\n            for child_node_id in node_data[\'childNodeId\']:\n                generate_node_code(child_node_id, indent + "    ", head_node_id)\n\n        elif node_type == \'variableSet\':\n            key = node_data[\'internalData\'][\'key\']\n            code.append(f"{indent}{key} = {head_node_id}")\n            for child_node_id in node_data[\'childNodeId\']:\n                generate_node_code(child_node_id, indent, key)\n\n        elif node_type == \'functionWrapper\':\n            for child_node_id in node_data[\'childNodeId\']:\n                generate_node_code(child_node_id, indent, f"node{node_data[\'headNodeId\'][0]}")\n\n    generate_node_code(start_node_id)\n    return "\\n".join(code)\n\n# Example usage\ngenerated_code = generate_code(node_system_output)\nprint(generated_code)\ ...

# %%
print(message.content[0].text)
# Out:
# To implement the `variableSet` node so that it saves the output of its head node to a variable with the specified key and passes it to the next node as input, you can modify the `generate_code` function as follows:
#
# ```python
# import json
#
# def generate_code(node_system):
#     code = []  # Initialize code as an empty list
#     global_variables = {}
#
#     # Extract global variables
#     for node_id, node_data in node_system.items():
#         if node_data['type'] == 'globalVariable':
#             key = node_data['internalData']['key']
#             value = node_data['internalData']['valueHolder']
#             method = node_data['internalData']['method']
#             global_variables[key] = (value, method)
#
#     # Generate global variable assignments
#     for key, (value, method) in global_variables.items():
#         if method == 'string':
#             code.append(f"{key} = '{value}'")
#         else:
#             code.append(f"{key} = {value}")
#
#     # Find the starting node
#     start_node_id = None
#     for node_id, node_data in node_system.items():
#         if node_data['type'] == 'fbWebhook' and not node_data['headNodeId']:
#             start_node_id = node_id
#             break
#
#     # Generate code for each node
#     visited_nodes = set()
#     def generate_node_code(node_id, indent="", head_node_id=None):
#         if node_id in visited_nodes:
#             return
#         visited_nodes.add(node_id)
#
#         node_data = node_system[node_id]
#         node_type = node_data['type']
#
#         if node_type == 'fbWebhook':
#             code_line = f"{indent}fbWebhook()"
#             code_line = f"{indent}node{node_id} = " + code_line
#             code.append(code_line)
#             for child_node_id in node_data['childNodeId']:
#                 generate_node_code(child_node_id, indent, f"node{node_id}")
#
#         elif node_type == 'llmGenerate':
#             system_prompt = node_data['internalData']['systemPrompt']
#             user_prompt = node_data['internalData']['userPrompt']
#             code_line = f"{indent}llmGenerate('{system_prompt}', '{user_prompt}', {head_node_id})"
#             code_line = f"{indent}node{node_id} = " + code_line
#             code.append(code_line)
#             for child_node_id in node_data['childNodeId']:
#                 generate_node_code(child_node_id, indent, f"node{node_id}")
#
#         elif node_type == 'extractOutput':
#             code_line = f"{indent}extractOutput({head_node_id})"
#             code_line = f"{indent}node{node_id} = " + code_line
#             code.append(code_line)
#             for child_node_id in node_data['childNodeId']:
#                 generate_node_code(child_node_id, indent, f"node{node_id}")
#
#         elif node_type == 'switch':
#             code.append(f"{indent}match {head_node_id}:")
#             for child_node_id in node_data['childNodeId']:
#                 generate_node_code(child_node_id, indent + "    ", head_node_id)
#
#         elif node_type == 'switchCase':
#             input_value = node_data['internalData']['input']
#             code.append(f"{indent}case '{input_value}':")
#             for child_node_id in node_data['childNodeId']:
#                 generate_node_code(child_node_id, indent + "    ", head_node_id)
#
#         elif node_type == 'variableSet':
#             key = node_data['internalData']['key']
#             code.append(f"{indent}{key} = {head_node_id}")
#             for child_node_id in node_data['childNodeId']:
#                 generate_node_code(child_node_id, indent, key)
#
#         elif node_type == 'functionWrapper':
#             for child_node_id in node_data['childNodeId']:
#                 generate_node_code(child_node_id, indent, f"node{node_data['headNodeId'][0]}")
#
#     generate_node_code(start_node_id)
#     return "\n".join(code)
#
# # Example usage
# generated_code = generate_code(node_system_output)
# print(generated_code)
# ```
#
# In the modified code, the `variableSet` node is handled as follows:
#
# 1. It retrieves the `key` from the `internalData` of the node.
# 2. It generates a code line that assigns the value of the head node (`head_node_id`) to the variable with the specified `key`.
# 3. It passes the `key` as the `head_node_id` to the next node, so that the next node can use the variable as input.
#
# With these changes, the `variableSet` node will save the output of its head node to a variable with the specified key and pass that variable as input to the next node.

# %%
import json

def generate_code(node_system):
    code = []  # Initialize code as an empty list
    global_variables = {}

    # Extract global variables
    for node_id, node_data in node_system.items():
        if node_data['type'] == 'globalVariable':
            key = node_data['internalData']['key']
            value = node_data['internalData']['valueHolder']
            method = node_data['internalData']['method']
            global_variables[key] = (value, method)

    # Generate global variable assignments
    for key, (value, method) in global_variables.items():
        if method == 'string':
            code.append(f"{key} = '{value}'")
        else:
            code.append(f"{key} = {value}")

    # Find the starting node
    start_node_id = None
    for node_id, node_data in node_system.items():
        if node_data['type'] == 'fbWebhook' and not node_data['headNodeId']:
            start_node_id = node_id
            break

    # Generate code for each node
    visited_nodes = set()
    def generate_node_code(node_id, indent="", head_node_id=None):
        if node_id in visited_nodes:
            return
        visited_nodes.add(node_id)

        node_data = node_system[node_id]
        node_type = node_data['type']

        if node_type == 'fbWebhook':
            code_line = f"{indent}fbWebhook()"
            code_line = f"{indent}node{node_id} = " + code_line
            code.append(code_line)
            for child_node_id in node_data['childNodeId']:
                generate_node_code(child_node_id, indent, f"node{node_id}")

        elif node_type == 'llmGenerate':
            system_prompt = node_data['internalData']['systemPrompt']
            user_prompt = node_data['internalData']['userPrompt']
            code_line = f"{indent}llmGenerate('{system_prompt}', '{user_prompt}', {head_node_id})"
            code_line = f"{indent}node{node_id} = " + code_line
            code.append(code_line)
            for child_node_id in node_data['childNodeId']:
                generate_node_code(child_node_id, indent, f"node{node_id}")

        elif node_type == 'extractOutput':
            code_line = f"{indent}extractOutput({head_node_id})"
            code_line = f"{indent}node{node_id} = " + code_line
            code.append(code_line)
            for child_node_id in node_data['childNodeId']:
                generate_node_code(child_node_id, indent, f"node{node_id}")

        elif node_type == 'switch':
            code.append(f"{indent}match {head_node_id}:")
            for child_node_id in node_data['childNodeId']:
                generate_node_code(child_node_id, indent + "    ", head_node_id)

        elif node_type == 'switchCase':
            input_value = node_data['internalData']['input']
            code.append(f"{indent}case '{input_value}':")
            for child_node_id in node_data['childNodeId']:
                generate_node_code(child_node_id, indent + "    ", head_node_id)

        elif node_type == 'variableSet':
            key = node_data['internalData']['key']
            code.append(f"{indent}{key} = {head_node_id}")
            for child_node_id in node_data['childNodeId']:
                generate_node_code(child_node_id, indent, key)

        elif node_type == 'functionWrapper':
            for child_node_id in node_data['childNodeId']:
                generate_node_code(child_node_id, indent, f"node{node_data['headNodeId'][0]}")

    generate_node_code(start_node_id)
    return "\n".join(code)

# Example usage
generated_code = generate_code(node_system_output)
print(generated_code)
# Out:
# node11 = fbWebhook()
# userMessage = node11
# node12 = llmGenerate('Test', 'WE', userMessage)
